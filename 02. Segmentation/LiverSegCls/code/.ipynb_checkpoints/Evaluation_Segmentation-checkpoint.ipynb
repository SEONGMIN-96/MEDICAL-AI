# %%
import torch
import glob
import shutil
import os

print('Number of available devices ', torch.cuda.device_count())
# GPU 할당 변경하기

gpu_ids = 0  # 원하는 GPU 번호 입력
device = torch.device(f'cuda:{gpu_ids}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
print('Current devices ', torch.cuda.current_device())

from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, datasets, models
from loss_function import *
from dataload_eval import *
from utils import *
from metrics import *
import pandas as pd
from model import *

# I expect to see RuntimeWarnings in this block

## 트레이닝 파라메터 설정하기
batch_size = 1
print(os.getcwd())
os.chdir('/home/ubuntu/gcubme_ai/Workspace/SM_KANG/workspace/liber_seg_cls')
data_dir =  './data/20220320_segmentation/220320_Dataset_raw'
ckpt_dir = './result/20220320_segmentation/checkpoint'

log_dir = './result/20220320_segmentation/log'
result_dir = './result/20220320_segmentation/result2'

mode = 'train'
train_continue = 'off'
kf_type = True

# device = 'cpu'
print("device: ", device)
print("batch size: %d" % batch_size)
print("data dir: %s" % data_dir)
print("ckpt dir: %s" % ckpt_dir)
print("log dir: %s" % log_dir)
print("result dir: %s" % result_dir)
print("mode: %s" % mode)
print("GPU ID : %s" % gpu_ids)
print("K-fold cross validation : %s" % str(kf_type))

## 디렉토리 생성하기
if not os.path.exists(result_dir):
    os.makedirs(os.path.join(result_dir, 'png'))
    os.makedirs(os.path.join(result_dir, 'numpy'))
    
def make_folder(pathL):
    for path in pathL:

        os.makedirs(os.path.join(result_dir, 'test', path))
    
def remove_folder(pathL):
    for path in pathL:
        if os.path.exists(os.path.join(result_dir, 'test', path)):
            shutil.rmtree(os.path.join(result_dir, 'test', path))


folderNames = [ 'Success_box_ns', 'Fail_box_ns',  'Success_box', 'Fail_box','Success', 'Fail','False_Positive','True_Negative','Crowd']
#remove_folder(folderNames)
#make_folder(folderNames)

## 그밖에 부수적인 functions 설정하기
fn_tonumpy = lambda x: x.to('cpu').detach().numpy().transpose(0, 2, 3, 1)
fn_denorm = lambda x, mean, std: (x * std) + mean
fn_class = lambda x: 1.0 * (x > 0.5)

## Tensorboard 를 사용하기 위한 SummaryWriter 설정
writer_train = SummaryWriter(log_dir=os.path.join(log_dir, 'train'))
writer_val = SummaryWriter(log_dir=os.path.join(log_dir, 'val'))
# early_stopping object의 초기화

# TEST MODE
# TEST MODE


from torchvision.models.segmentation.deeplabv3 import DeepLabHead
from PIL import Image
import scipy
# Out:
# Number of available devices  4
# Current devices  2
# /home/ubuntu/gcubme_ai/Workspace/S_Oh/US_Liver
# device:  cuda:2
# batch size: 1
# data dir: ./data/20220320_segmentation/220320_Dataset_raw
# ckpt dir: ./result/20220320_segmentation/checkpoint
# log dir: ./result/20220320_segmentation/log
# result dir: ./result/20220320_segmentation/result2
# mode: train
# GPU ID : 2
# K-fold cross validation : True

# %%
from skimage import morphology
from scipy.signal import medfilt

def postprocessing(img,small_area):


    img = img / 255

    out1 = medfilt(img, 7)

    
    out3 = (morphology.remove_small_objects(out1.astype('bool'), small_area, connectivity=1) * 255).astype('uint8')
    
    
    return out3

# %%
def makeMask(img, w, h):
    maskpoint = np.array([[xx, yy] for xx, yy in zip(w, h)], dtype=np.int32)
    mask = cv2.fillPoly(img, [maskpoint], (255, 255, 255))

    return mask


from sklearn.metrics import jaccard_score

# %%
def IoU_cal(output, target):
    output_i = (output.reshape(output.shape[1] * output.shape[0]) / 255)
    target_i = (target.reshape(target.shape[1] * target.shape[0]) / 255)
    iou = round(jaccard_score(target_i, output_i, labels=np.unique(target_i), pos_label=1, average='binary'), 3)

    return iou

# %%
from torchvision import transforms, datasets, models

def draw_bbox(img,mask,size_re1,size_re2):
    if np.sum(mask) > 0:

        min_side = int(size_re1/8)
        y1 = np.min(np.where(mask == 255)[0]) 
        y2 = np.max(np.where(mask == 255)[0])
        x1 = np.min(np.where(mask == 255)[1]) 
        x2 = np.max(np.where(mask == 255)[1])

        box_fill = np.zeros((size_re1,size_re2))
        box_fill[y1-2:y2+1+2,x1-2:x2+1+2] = 255
        bbox = box_fill.copy()
        bbox[y1:y2+1, x1:x2+1] = 0

        img_bbox = img[y1:y2+1,x1:x2+1]
    else:
        box_fill = np.zeros((size_re1,size_re2))
        bbox = np.zeros((size_re1,size_re2))
        img_bbox = np.zeros((size_re1,size_re2))
    
    return box_fill, bbox, img_bbox

# %%
def draw_bbox_total(label, output,size1, size2):
    
    bbox_arr_label = np.zeros((size1, size2))
    bbox_arr_output = np.zeros((size1, size2))
    
    bbox_fill_label = bbox_arr_label.copy()
    bbox_fill_output = bbox_arr_output.copy()

    #zero_arr_total = zero_arr.copy()
    if np.sum(label) >0:
        #ret, imthres = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

        # 가장 바깥쪽 컨투어에 대해 모든 좌표 반환 ---③
        contour, _ = cv2.findContours(label, cv2.RETR_EXTERNAL, \
                                                         cv2.CHAIN_APPROX_NONE)
        N = len(contour)

        for i in range(0, N):
            xMax = np.max(contour[i][:,0,0])
            xMin = np.min(contour[i][:,0,0])
            yMax = np.max(contour[i][:,0,1])
            yMin = np.min(contour[i][:,0,1])
            
            bbox_arr_label[yMin-2:yMax+1+2, xMin-2:xMax+1+2] = 255
            bbox_fill_label = bbox_arr_label.copy()
            
            
            bbox_arr_label[yMin:yMax+1, xMin:xMax+1] = 0
            
    if np.sum(output) >0:
        #ret, imthres = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

        # 가장 바깥쪽 컨투어에 대해 모든 좌표 반환 ---③
        contour, _ = cv2.findContours(output, cv2.RETR_EXTERNAL, \
                                                         cv2.CHAIN_APPROX_NONE)
        N = len(contour)

        for i in range(0, N):
            xMax = np.max(contour[i][:,0,0])
            xMin = np.min(contour[i][:,0,0])
            yMax = np.max(contour[i][:,0,1])
            yMin = np.min(contour[i][:,0,1])
            
            bbox_arr_output[yMin-2:yMax+1+2, xMin-2:xMax+1+2] = 255
            bbox_fill_output = bbox_arr_output.copy()
            
            
            bbox_arr_output[yMin:yMax+1, xMin:xMax+1] = 0

    
    return  bbox_arr_label, bbox_arr_output, bbox_fill_label, bbox_fill_output

# %%
import cv2
import matplotlib.pyplot as plt
def multi_object(mask,size1,size2):
    
    img_list= []
    
    if np.sum(mask) >0:
        #ret, imthres = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

        # 가장 바깥쪽 컨투어에 대해 모든 좌표 반환 ---③
        contour, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, \
                                                         cv2.CHAIN_APPROX_NONE)
        N = len(contour)

        for i in range(0, N):
            img = np.zeros( (size1, size2) ) # create a single channel 200x200 pixel black image 
            img2= cv2.fillPoly(img, pts =[contour[i]], color=(255,255,255))
            img_list +=[img2]
    else:
        N =0
    
    return img_list, N

# %%
def draw_bbox2(input_i, label_i,output_i, size_re1,size_re2):
    label_box_fill, label_bbox, _ = draw_bbox(input_i, label_i,size_re1,size_re2 )
    output_box_fill, output_bbox, img_bbox = draw_bbox(input_i, output_i, size_re1,size_re2 )
    label_sum = label_bbox + label_i
    output_sum = output_bbox + output_i
    
    return label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox

# %%
def make_box(input_i,label_i, output_i, label_i_list,output_i_list, label_N ,output_N,size_re1,size_re2,  ID,result_dir,df_ps):
    ## Single object
    dice_arr =[]
    iou_arr = []
    img_box_arr = []
    id_arr =[]
    ID_sp = ID.split('.tiff')[0]
    label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total = draw_bbox_total(label_i, output_i,size_re1,size_re2)

    if label_N == 1 and output_N == 1:  ## True positive
        label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox = draw_bbox2(input_i,label_i_list[0],output_i_list[0], size_re1,size_re2 )
        Dice, IoU = make_metricNcaseImg(input_i,label_i, output_i, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total, label_i_list[0],output_i_list[0],label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox, ID,result_dir, size_re1,size_re2, output_bbox, label_bbox,df_ps)
        dice_arr +=[Dice]
        iou_arr +=[IoU]
        img_box_arr += [img_bbox]
        id_arr += [ID]


        
    elif label_N >= 1 and output_N == 0: ## False negative
        for i in range(0,label_N):
            label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox = draw_bbox2(input_i, label_i_list[i], np.zeros((size_re1,size_re2)), size_re1,size_re2)
            Dice, IoU = make_metricNcaseImg(input_i,label_i, output_i, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total,  label_i_list[i], np.zeros((size_re1,size_re2)),label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox,ID,result_dir, size_re1,size_re2, output_bbox, label_bbox,df_ps)
            dice_arr +=[Dice]
            iou_arr +=[IoU]
            ID = ID_sp.split('.tiff')[0] +str(i)+'.tiff'
            id_arr += [ID]

    
    
    ## Multi object
    else:
        IoU_L = []
        ii_L = []
        jj_L =[]
        count = 0

        for ii in range(0,label_N):
            label_box_fill, label_bbox, _ = draw_bbox(input_i, label_i_list[ii], size_re1,size_re2 )

            for jj in range(0, output_N):
                output_box_fill, output_bbox, img_bbox = draw_bbox(input_i, output_i_list[jj], size_re1,size_re2 )

                Dice, IoU = metrics_eval(output_box_fill/255, label_box_fill/255, size_re1,size_re2)
                IoU_L +=[IoU]
                ii_L += [ii]
                jj_L += [jj]
        df = pd.DataFrame(data ={'Label_n': ii_L, 'Pred_n': jj_L, 'IoU': IoU_L})
        Label_n = np.array(ii_L)
        Pred_n = np.array(jj_L)
        
        jj_L0 = np.unique(jj_L)
        output_count = output_N
        label_count = label_N
        pred_remain = np.arange(0,output_N,1)
        label_remain = np.arange(0, label_N,1)
        
        pred_uni = np.unique(list(df['Pred_n']))
        pred_uni_N = len(pred_uni)
        
        label_uni = np.unique(list(df['Label_n']))
        label_uni_N = len(label_uni)
            
        df2 = df.copy()
        
        pred_list = []
        label_list = []
        
        while len(df) > 0:

            idx = np.argmax(df['IoU'])
            
            print(df.iloc[idx]['Pred_n'])
           
            pred_idx = int(df.iloc[idx]['Pred_n'])
            label_idx = int(df.iloc[idx]['Label_n'] )
            
            pred_list +=[pred_idx]
            label_list +=[label_idx]
            
            count += 1
            ID =  ID_sp+str(count)+'.tiff'
                
            label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox = draw_bbox2(input_i, label_i_list[label_idx], output_i_list[pred_idx],size_re1,size_re2)
            Dice, IoU = make_metricNcaseImg(input_i,label_i, output_i, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total, label_i_list[label_idx], output_i_list[pred_idx],label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox, ID,result_dir, size_re1,size_re2,output_bbox, label_bbox,df_ps)
            dice_arr +=[Dice]
            iou_arr +=[IoU]
            img_box_arr += [img_bbox]
            id_arr += [ID]

            df = df[df['Pred_n'] != pred_idx]
            df = df[df['Label_n'] != label_idx]
            
        if label_uni_N > pred_uni_N:
            
            for i in range(0, len(label_list)):
                df2 = df2[(df2['Pred_n'] != pred_list[i]) | (df2['Label_n'] != label_list[i])]
                
            for i in range(0, len(df2)):
                label_idx = int(df2.iloc[i]['Label_n'])
                count += 1
                ID =  ID_sp+str(count)+'.tiff'
                             
                label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox = draw_bbox2(input_i,label_i_list[label_idx], np.zeros((size_re1,size_re2)),size_re1,size_re2)
                Dice, IoU = make_metricNcaseImg(input_i,label_i, output_i, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total, label_i_list[label_idx], np.zeros((size_re1,size_re2)),label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox, ID,result_dir, size_re1,size_re2,output_bbox, label_bbox,df_ps)
                dice_arr +=[Dice]
                iou_arr +=[IoU]
                img_box_arr += [img_bbox]
                id_arr += [ID]


                
                
        elif label_uni_N < pred_uni_N:
            
            for i in range(0, len(label_list)):
                df2 = df2[(df2['Pred_n'] != pred_list[i]) | (df2['Label_n'] != label_list[i])]
                
            for i in range(0, len(df2)):
                pred_idx = int(df2.iloc[i]['Pred_n'])
                count += 1
                ID =  ID_sp+str(count)+'.tiff'
                
                
                label_sum, output_sum,label_box_fill,output_box_fill, img_bbox, output_bbox, label_bbox = draw_bbox2(input_i, np.zeros((size_re1,size_re2)), output_i_list[pred_idx], size_re1,size_re2)
                Dice, IoU = make_metricNcaseImg(input_i,label_i, output_i, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total,  np.zeros((size_re1,size_re2)), output_i_list[pred_idx], label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox, ID,result_dir, size_re1,size_re2,output_bbox, label_bbox,df_ps)
                dice_arr +=[Dice]
                iou_arr +=[IoU]
                img_box_arr += [img_bbox]
                id_arr += [ID]


    return  dice_arr, iou_arr, img_box_arr,  id_arr

# %%
def make_metricNcaseImg(input_i, label_total, output_total, label_bbox_total, output_bbox_total, bbox_fill_label_total, bbox_fill_output_total, label_i, output_i, label_sum, output_sum,label_box_fill,output_box_fill,  img_bbox,ID,result_dir, size_re1,size_re2, output_bbox, label_bbox,df_ps):

    backtorgb = cv2.cvtColor(input_i, cv2.COLOR_GRAY2RGB)
    
    if np.sum(output_i) > 0:
        y1=int(np.min(np.where(output_bbox == 255)[0]))
        y2=int(np.max(np.where(output_bbox == 255)[0]))
        x1=int(np.min(np.where(output_bbox == 255)[1]))
        x2=int(np.max(np.where(output_bbox == 255)[1]))
        y_diff = y2-y1
        x_diff = x2-x1
        diff = abs((y_diff - x_diff)/2)            
        p1 = int(np.ceil(diff))
        p2 = int(np.floor(diff))
        
        if x_diff >= y_diff:
            y2_2 =y2+p2
            y1_2 =y1-p1
            x2_2 =x2
            x1_2 =x1   
            
        else:
            x2_2 =x2 + p2
            x1_2 =x1 - p1      
            y2_2 =y2
            y1_2 =y1  

        #backtorgb2 = backtorgb[y1:y2, x1:x2,:] 
        #output_i2 = output_i[y1:y2, x1:x2] 
        #backtorgb3 =  backtorgb2.copy()
        #backtorgb3[output_i2 == 0,:] = 0
        
        backtorgb2_2 = backtorgb[y1_2:y2_2, x1_2:x2_2,:] 
        output_i2_2 = output_i[y1_2:y2_2, x1_2:x2_2] 
        #backtorgb3_2 =  backtorgb2_2.copy()
        #backtorgb3_2[output_i2_2 == 0,:] = 0
        
    zero_box = np.zeros((size_re1, size_re2, 1))
    
    ###############################################################################

    label_rgb = np.concatenate(
        (label_i[:, :, np.newaxis], zero_box, zero_box),
        axis=2).astype('uint8')
    
    output_rgb = np.concatenate(
        (zero_box, zero_box, output_i[:, :, np.newaxis]),
        axis=2).astype('uint8')
    
    label_box_rgb = np.concatenate(
        ((label_bbox)[:, :, np.newaxis], zero_box, zero_box),
        axis=2).astype('uint8')
    
    output_box_rgb = np.concatenate(
        (zero_box, zero_box, (output_bbox)[:, :, np.newaxis]),
        axis=2).astype('uint8')
    
    backtorgb_box = backtorgb.copy()
    
    backtorgb_box[label_bbox == 255] = 0
    backtorgb_box[output_bbox == 255] = 0
    
    concat_img = (((backtorgb / 255) + (label_rgb / 255) + (output_rgb / 255)))

    concat_box = (((backtorgb_box / 255) + (label_box_rgb / 255) + (output_box_rgb / 255)))
    
    ###############################################################################
    #label_rgb_total = np.concatenate((label_total[:, :, np.newaxis], zero_box, zero_box),axis=2).astype('uint8')
    #print('output_total: ', np.shape(output_total))
    #print('output_bbox_total:', np.shape(output_bbox_total))
    #print('zero_box: ', np.shape(zero_box))
    
    
    
    #output_rgb_total = np.concatenate((zero_box, zero_box, output_total[:, :, np.newaxis]), axis=2).astype('uint8')
    #label_box_rgb_total = np.concatenate(((label_bbox_total)[:, :, np.newaxis], zero_box, zero_box),axis=2).astype('uint8')
    #output_box_rgb_total = np.concatenate((zero_box, zero_box, (output_bbox_total)[:, :, np.newaxis]), axis=2).astype('uint8')
    #backtorgb_total = backtorgb.copy()
    #backtorgb_box_total = backtorgb.copy()
    
    backtorgb_box_total[label_bbox_total == 255] = 0
    backtorgb_box_total[output_bbox_total == 255] = 0
    
    #concat_img_total = (((backtorgb_total / 255) + (label_rgb_total / 255) + (output_rgb_total / 255)))
    
    #concat_box_total = (((backtorgb_box_total / 255) + (label_box_rgb_total / 255) + (output_box_rgb_total / 255)))
    
    
    #######################################################################################################
    backtorgb_FP = backtorgb.copy()
    backtorgb_box_FP = backtorgb.copy()
    
    concat_img_FP = (((backtorgb_FP / 255) + (label_rgb_total / 255) + (output_rgb / 255)))
    
    
    concat_box_FP = (((backtorgb_box_FP / 255) + (label_box_rgb_total / 255) + (output_box_rgb / 255)))

    


    Dice, IoU = metrics_eval((output_box_fill/255), (label_box_fill/255), size_re1, size_re2)
    
    Dice_FP, IoU_FP = metrics_eval((output_box_fill/255), (bbox_fill_label_total/255), size_re1, size_re2)
    
    
    concat_img = cv2.resize(concat_img, (512,512), interpolation=cv2.INTER_CUBIC)
    concat_box = cv2.resize(concat_box, (512,512), interpolation=cv2.INTER_CUBIC)
    #concat_img_total = cv2.resize(concat_img_total, (512,512), interpolation=cv2.INTER_CUBIC)
    #concat_box_total = cv2.resize(concat_box_total, (512,512), interpolation=cv2.INTER_CUBIC)
    concat_img_FP = cv2.resize(concat_img_FP, (512,512), interpolation=cv2.INTER_CUBIC)
    concat_box_FP = cv2.resize(concat_box_FP, (512,512), interpolation=cv2.INTER_CUBIC)
    
    concat_img[concat_img > 1] = 1
    concat_box[concat_box > 1] = 1

    #concat_img_total[concat_img_total > 1] = 1
    #concat_box_total[concat_box_total > 1] = 1
    concat_img_FP[concat_img_FP > 1] = 1
    concat_box_FP[concat_box_FP > 1] = 1

    concat_img[concat_img < 0] = 0
    concat_box[concat_box < 0] = 0

    #concat_img_total[concat_img_total < 0] = 0
    #concat_box_total[concat_box_total < 0] = 0
    concat_img_FP[concat_img_FP < 0] = 0
    concat_box_FP[concat_box_FP < 0] = 0



        
    if (np.sum(output_i) > 0) and (IoU_FP == 0):  ## False positive
        IoU = -1
        Dice = -1 


    
    if np.sum(label_i)> 0:


            

        print('id: ',ID)
        print('IoU: ', IoU)
        



        if (IoU >= 0.20):

            plt.imsave(os.path.join(result_dir, 'test',  'Success', ID),concat_img)
            plt.imsave(os.path.join(result_dir, 'test',  'Success','box_'+ID),concat_box)

            
            #plt.imsave(os.path.join(result_dir, 'test',  'Success', 'Total_'+ID),concat_img_total)
            #plt.imsave(os.path.join(result_dir, 'test',  'Success','Total_box_'+ID),concat_box_total)


            
            plt.imsave(os.path.join(result_dir, 'test',  'Success_box',ID), backtorgb2_2)
            
            
        else:
            
            print('Fail')
            plt.imsave(os.path.join(result_dir, 'test',  'Fail', ID),concat_img)
            plt.imsave(os.path.join(result_dir, 'test',  'Fail','box_'+ID),concat_box)
            #plt.imsave(os.path.join(result_dir, 'test',  'Fail', 'Total_'+ID),concat_img_total)
            #plt.imsave(os.path.join(result_dir, 'test',  'Fail','Total_box_'+ID),concat_box_total)

  
            
        if (IoU == -1):
            plt.imsave(os.path.join(result_dir, 'test',  'False_Positive', ID),concat_img)
            plt.imsave(os.path.join(result_dir, 'test',  'False_Positive','box_'+ID),concat_box)
            #plt.imsave(os.path.join(result_dir, 'test',  'False_Positive', 'Total_'+ ID),concat_img_FP)
            #plt.imsave(os.path.join(result_dir, 'test',  'False_Positive','Total_box_'+ID),concat_box_FP)


    elif np.sum(label_i) ==0 and np.sum(output_i)> 0:
        if (IoU_FP == 0): ## 'False Positive'
            Dice= -1
            IoU = -1
            print('id: ',ID)
            print('False Positive')
            plt.imsave(os.path.join(result_dir, 'test',  'False_Positive', ID),concat_img)
            plt.imsave(os.path.join(result_dir, 'test',  'False_Positive','box_'+ID),concat_box)
            #plt.imsave(os.path.join(result_dir, 'test',  'False_Positive', 'Total_'+ ID),concat_img_FP)
            #plt.imsave(os.path.join(result_dir, 'test',  'False_Positive','Total_box_'+ID),concat_box_FP)

        else: ## 'Crowd'
            Dice= -2
            IoU = -2
            plt.imsave(os.path.join(result_dir, 'test',  'Crowd', 'Total_'+ ID),concat_img_FP)
            plt.imsave(os.path.join(result_dir, 'test',  'Crowd','Total_box_'+ID),concat_box_FP)


    elif np.sum(label_i) ==0 and np.sum(output_i)== 0: ## True Negative
            Dice= -3
            IoU = -3
            plt.imsave(os.path.join(result_dir, 'test',  'True_Negative', 'Total_'+ ID),concat_img_total)
            plt.imsave(os.path.join(result_dir, 'test',  'True_Negative','Total_box_'+ID),concat_box_total)


        
    print(Dice)
    print(IoU)

    
    return Dice, IoU

# %%
# Out:
# Number of available devices  4
# Current devices  1
# /home/ubuntu/gcubme_ai/Workspace/S_Oh/US_Liver
# device:  cuda:1
# batch size: 1
# data dir: ./data/20220320_segmentation/220320_Dataset_raw
# ckpt dir: ./result/20220320_segmentation/checkpoint
# log dir: ./result/20220320_segmentation/log
# result dir: ./result/20220320_segmentation/result
# mode: train
# GPU ID : 1
# K-fold cross validation : True

# %%
def save_best_npy(FOLD, testPath,df_ps):
    import matplotlib.pyplot as plt

    transform2 = transforms.Compose([Normalization(), ToTensor()])
    dataset_test = Dataset(data_dir=testPath, transform=transform2, target_transform=transform2)
    print(dataset_test )

    # 그밖에 부수적인 variables 설정하기
    num_data_test = len(dataset_test)
    print(num_data_test )

    ## 네트워크 생성하기
    deeplab = models.segmentation.deeplabv3_resnet101(pretrained=True)
    deeplab.backbone.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
    deeplab.classifier = DeepLabHead(2048, 1)
    net = deeplab.to(device)

    ## Optimizer 설정하기
    optim = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9,  weight_decay=0.0001)

    loader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, num_workers=0)
    
    print(loader_test )

    best_model_name = [j for j in os.listdir(ckpt_dir) if 'best_fold' + str(FOLD) in j][0]
    
    print((ckpt_dir))
    
    print(best_model_name )

    dict_model = torch.load('%s/%s' % (ckpt_dir, best_model_name),map_location = 'cuda:2')

    net.load_state_dict(dict_model['net'])
    optim.load_state_dict(dict_model['optim'])
    

    
    #######################################################
    with torch.no_grad():
        print('step 1 --------------------------------')
        net.eval()

        count_total = 0

        dice_arr = []
        iou_arr = []
        fname_arr =[]
        
        dice_seg_arr = []
        iou_seg_arr = []
        fname_seg_arr =[]
        
        
        id_arr = []
        id_arr2  = []


        for batch, data in enumerate(loader_test, 1):
            print('step 2 --------------------------------')
            count = 0

            input_id = data['Input_ID']
            input_id1 = [i.split('/')[-1] for i in input_id]


            if data['Input_ID'][count].split('_img.')[0] != data['Label_ID'][count].split('_mask.')[0]:
                print('error!!!!!!!!!!!!!!!')
                break

            label = data['label'].to(device)
            input = data['input'].to(device)
            
            input_raw = data['input_raw']
            label_raw = data['label_raw']

            output = net(input)['out']
            sig = nn.Sigmoid()
            output = sig(output)

            # Tensorboard 저장하기
            label = fn_tonumpy(label)
            input = fn_tonumpy(input)
            output = fn_tonumpy(fn_class(output))

          
            

            
            for j in range(label.shape[0]):
                


                
                ID= data['Input_ID'][j]
                print('ID: ', ID)

                #print('small area: ', small_area)
                
                #input_i = (input[j].squeeze() * 255).astype('uint8')
                #label_i = (label[j].squeeze() * 255).astype('uint8')
                #output_i = (output[j].squeeze() * 255).astype('uint8')
                #label_i =cv2.resize(label, (input_raw.shape[0], input_raw.shape[1])
                output_i = output[j][:,:,0]

                
                input_i = input_raw[j][:,:,0].numpy()
                label_i = label_raw[j][:,:,0].numpy()
                print('label_i.shape: ', label_i.shape)
                print('output_i.shape: ', output_i.shape)
                output_i =cv2.resize(output_i, (label_i.shape[1], label_i.shape[0]), interpolation=cv2.INTER_NEAREST)
                
                img_fid = ID.split('_class')[0]
                ps = df_ps[df_ps['fid'] == img_fid ]['ps'].values
 
                small_area = int(0.25/(ps*ps))
    
    
                output_i = postprocessing(output_i,small_area)
                
                Dice_seg, IoU_seg = metrics_eval((output_i/255).astype('int'), (label_i/255).astype('int'),label_i.shape[1], label_i.shape[0])
            
                dice_seg_arr += [Dice_seg]
                iou_seg_arr += [IoU_seg]
                
 
                print('label_i.shape: ', label_i.shape)
                print('output_i.shape: ', output_i.shape)
                
                print('label_i.max: ', np.max(label_i))
                print('output_i.max: ', np.max(output_i))

                
                size_re1 = label_i.shape[0]
                size_re2 = label_i.shape[1]
                
                label_i_list, label_N=multi_object(label_i ,size_re1,size_re2)
                output_i_list, output_N=multi_object(output_i ,size_re1,size_re2)
                            
                Dice, IoU,imgBox, idArr = make_box(input_i,label_i, output_i, label_i_list,output_i_list, label_N ,output_N,size_re1,size_re2,  ID ,result_dir,df_ps)
                dice_arr +=Dice
                iou_arr +=IoU
                fname_arr += [ID]
                
                print('len(dice_seg_arr): ', len(dice_seg_arr))
                print('len(dice_seg_arr): ', len(dice_seg_arr))
                print('len(iou_seg_arr): ', len(iou_seg_arr))
                
                types_num = ID.split('class_')[-1].split('_')[0]
                if types_num == '0':
                    types = 'HCC'
                elif types_num == '1':
                    types = 'Hemangioma'
                elif types_num == '2':
                    types = 'Cyst'
                id_arr2 +=[types]

                id_arr  += [types ]*len(Dice)
                count += 1
                count_total += 1

        results = pd.DataFrame(data={ 'IoU_detect': iou_arr,  'Type': id_arr})
        results.to_csv(os.path.join(result_dir, 'test', 'Results_Detection_all_' + str(FOLD) + '.csv'))
        
        results_seg = pd.DataFrame(data={'ID':fname_arr,'IoU_seg': iou_seg_arr,'DSC_seg': dice_seg_arr,  'Type': id_arr2})
        results_seg.to_csv(os.path.join(result_dir, 'test', 'Results_Segmentation_all_' + str(FOLD) + '.csv'))
        
        dsc_all_seg = np.mean(results_seg['DSC_seg'])
        iou_all_seg = np.mean(results_seg['IoU_seg'])
        df_seg = pd.DataFrame(data={'iou_all_seg': iou_all_seg,'dsc_all_seg': dsc_all_seg}, index=[0])

        iou_all = np.mean(results['IoU_detect'])
        df_detect1 = pd.DataFrame(data={'iou_all': iou_all}, index=[0])
        
        df_seg.to_csv(os.path.join(result_dir, 'test', 'Results_Segmentation' + str(FOLD) + '.csv'))
        df_detect1.to_csv(os.path.join(result_dir, 'test', 'Results_Detection' + str(FOLD) + '.csv'))

# %%
def get_cv(fold, data_dir):

    cv_num = [0,1,2,3,4]
    train = []

    for i in range(0,5):
        num = fold+i
        if num >=5:
            num = num-5
        if i <= 2:
            train_i = os.path.join(data_dir, 'CV'+str(cv_num[num]+1))
            train += [train_i]
        if i ==3:
            val = [os.path.join(data_dir, 'CV'+str(cv_num[num]+1))]
        if i == 4:
            test =  [os.path.join(data_dir, 'CV'+str(cv_num[num]+1))]

    return train, val, test

# %%
path = './data/20220320_segmentation/PS_info.csv'
df_ps = pd.read_csv(path)


for fold in range(0,5):
    FOLD = fold+1
    trainPath, valPath, testPath = get_cv(fold, data_dir)
    save_best_npy(FOLD, testPath,df_ps)
# Out:
# ---------------------------
# <dataload_eval.Dataset object at 0x7f772e51ee90>
# 1437
# <torch.utils.data.dataloader.DataLoader object at 0x7f772e557050>
# ./result/20220320_segmentation/checkpoint
# best_fold1_checkpoint.pth
# step 1 --------------------------------
# input_raw: 607
# label_raw: 607
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20120313_19650323_num_1_class_1_img.tiff
# label_i.shape:  (607, 607)
# output_i.shape:  (512, 512)
# label_i.shape:  (607, 607)
# output_i.shape:  (607, 607)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (607, 607)
# output_bbox_total: (607, 607)
# zero_box:  (607, 607, 1)
# id:  20120313_19650323_num_1_class_1_img1.tiff
# IoU:  0.395
# 0.566
# 0.395
# output_total:  (607, 607)
# output_bbox_total: (607, 607)
# zero_box:  (607, 607, 1)
# id:  20120313_19650323_num_1_class_1_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  1
# len(dice_seg_arr):  1
# len(iou_seg_arr):  1
# input_raw: 607
# label_raw: 607
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20120313_19650323_num_2_class_2_img.tiff
# label_i.shape:  (607, 607)
# output_i.shape:  (512, 512)
# label_i.shape:  (607, 607)
# output_i.shape:  (607, 607)
# label_i.max:  255
# output_i.max:  255
# output_total:  (607, 607)
# output_bbox_total: (607, 607)
# zero_box:  (607, 607, 1)
# id:  20120313_19650323_num_2_class_2_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  2
# len(dice_seg_arr):  2
# len(iou_seg_arr):  2
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_1_class_0_img.tiff
# IoU:  0.894
# 0.944
# 0.894
# len(dice_seg_arr):  3
# len(dice_seg_arr):  3
# len(iou_seg_arr):  3
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_2_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_2_class_1_img.tiff
# IoU:  0.714
# 0.833
# 0.714
# len(dice_seg_arr):  4
# len(dice_seg_arr):  4
# len(iou_seg_arr):  4
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_3_class_0_img.tiff
# IoU:  0.671
# 0.803
# 0.671
# len(dice_seg_arr):  5
# len(dice_seg_arr):  5
# len(iou_seg_arr):  5
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_4_class_0_img.tiff
# IoU:  0.872
# 0.932
# 0.872
# len(dice_seg_arr):  6
# len(dice_seg_arr):  6
# len(iou_seg_arr):  6
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_5_class_0_img.tiff
# IoU:  0.643
# 0.782
# 0.643
# len(dice_seg_arr):  7
# len(dice_seg_arr):  7
# len(iou_seg_arr):  7
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20130822_30558333_num_6_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20130822_30558333_num_6_class_0_img.tiff
# IoU:  0.691
# 0.817
# 0.691
# len(dice_seg_arr):  8
# len(dice_seg_arr):  8
# len(iou_seg_arr):  8
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181102_40224602_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181102_40224602_num_2_class_0_img.tiff
# IoU:  0.916
# 0.956
# 0.916
# len(dice_seg_arr):  9
# len(dice_seg_arr):  9
# len(iou_seg_arr):  9
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181102_40224602_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181102_40224602_num_3_class_0_img.tiff
# IoU:  0.814
# 0.898
# 0.814
# len(dice_seg_arr):  10
# len(dice_seg_arr):  10
# len(iou_seg_arr):  10
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181102_40224602_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181102_40224602_num_4_class_0_img.tiff
# IoU:  0.834
# 0.909
# 0.834
# len(dice_seg_arr):  11
# len(dice_seg_arr):  11
# len(iou_seg_arr):  11
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181102_40224602_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181102_40224602_num_5_class_0_img.tiff
# IoU:  0.836
# 0.911
# 0.836
# len(dice_seg_arr):  12
# len(dice_seg_arr):  12
# len(iou_seg_arr):  12
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181109_40166472_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181109_40166472_num_1_class_0_img.tiff
# IoU:  0.484
# 0.652
# 0.484
# len(dice_seg_arr):  13
# len(dice_seg_arr):  13
# len(iou_seg_arr):  13
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181109_40166472_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181109_40166472_num_2_class_0_img.tiff
# IoU:  0.684
# 0.812
# 0.684
# len(dice_seg_arr):  14
# len(dice_seg_arr):  14
# len(iou_seg_arr):  14
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181109_40166472_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181109_40166472_num_3_class_0_img.tiff
# IoU:  0.676
# 0.807
# 0.676
# len(dice_seg_arr):  15
# len(dice_seg_arr):  15
# len(iou_seg_arr):  15
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181109_40166472_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181109_40166472_num_4_class_0_img.tiff
# IoU:  0.722
# 0.839
# 0.722
# len(dice_seg_arr):  16
# len(dice_seg_arr):  16
# len(iou_seg_arr):  16
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181109_40166472_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181109_40166472_num_5_class_0_img.tiff
# IoU:  0.713
# 0.832
# 0.713
# len(dice_seg_arr):  17
# len(dice_seg_arr):  17
# len(iou_seg_arr):  17
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181114_19339513_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181114_19339513_num_1_class_0_img.tiff
# IoU:  0.868
# 0.929
# 0.868
# len(dice_seg_arr):  18
# len(dice_seg_arr):  18
# len(iou_seg_arr):  18
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181115_19385033_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181115_19385033_num_1_class_0_img.tiff
# IoU:  0.723
# 0.839
# 0.723
# len(dice_seg_arr):  19
# len(dice_seg_arr):  19
# len(iou_seg_arr):  19
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181115_19385033_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181115_19385033_num_2_class_0_img.tiff
# IoU:  0.628
# 0.771
# 0.628
# len(dice_seg_arr):  20
# len(dice_seg_arr):  20
# len(iou_seg_arr):  20
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181115_19385033_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181115_19385033_num_3_class_0_img.tiff
# IoU:  0.705
# 0.827
# 0.705
# len(dice_seg_arr):  21
# len(dice_seg_arr):  21
# len(iou_seg_arr):  21
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181119_21072983_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181119_21072983_num_1_class_0_img.tiff
# IoU:  0.787
# 0.881
# 0.787
# len(dice_seg_arr):  22
# len(dice_seg_arr):  22
# len(iou_seg_arr):  22
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181119_21072983_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181119_21072983_num_2_class_0_img.tiff
# IoU:  0.177
# Fail
# 0.301
# 0.177
# len(dice_seg_arr):  23
# len(dice_seg_arr):  23
# len(iou_seg_arr):  23
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181127_40253794_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181127_40253794_num_1_class_0_img1.tiff
# IoU:  0.087
# Fail
# 0.16
# 0.087
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181127_40253794_num_1_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  24
# len(dice_seg_arr):  24
# len(iou_seg_arr):  24
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181127_40253794_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181127_40253794_num_5_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  25
# len(dice_seg_arr):  25
# len(iou_seg_arr):  25
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181127_40253794_num_6_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181127_40253794_num_6_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  26
# len(dice_seg_arr):  26
# len(iou_seg_arr):  26
# input_raw: 1033
# label_raw: 1033
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181201_16373613_num_1_class_0_img.tiff
# label_i.shape:  (1033, 1033)
# output_i.shape:  (512, 512)
# label_i.shape:  (1033, 1033)
# output_i.shape:  (1033, 1033)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (1033, 1033)
# output_bbox_total: (1033, 1033)
# zero_box:  (1033, 1033, 1)
# id:  20181201_16373613_num_1_class_0_img1.tiff
# IoU:  -1
# Fail
# -1
# -1
# output_total:  (1033, 1033)
# output_bbox_total: (1033, 1033)
# zero_box:  (1033, 1033, 1)
# id:  20181201_16373613_num_1_class_0_img2.tiff
# False Positive
# -1
# -1
# output_total:  (1033, 1033)
# output_bbox_total: (1033, 1033)
# zero_box:  (1033, 1033, 1)
# id:  20181201_16373613_num_1_class_0_img3.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  27
# len(dice_seg_arr):  27
# len(iou_seg_arr):  27
# input_raw: 496
# label_raw: 496
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181201_19367983_num_1_class_0_img.tiff
# label_i.shape:  (496, 496)
# output_i.shape:  (512, 512)
# label_i.shape:  (496, 496)
# output_i.shape:  (496, 496)
# label_i.max:  255
# output_i.max:  255
# output_total:  (496, 496)
# output_bbox_total: (496, 496)
# zero_box:  (496, 496, 1)
# id:  20181201_19367983_num_1_class_0_img.tiff
# IoU:  0.78
# 0.876
# 0.78
# len(dice_seg_arr):  28
# len(dice_seg_arr):  28
# len(iou_seg_arr):  28
# input_raw: 508
# label_raw: 508
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181201_19367983_num_2_class_0_img.tiff
# label_i.shape:  (508, 508)
# output_i.shape:  (512, 512)
# label_i.shape:  (508, 508)
# output_i.shape:  (508, 508)
# label_i.max:  255
# output_i.max:  255
# output_total:  (508, 508)
# output_bbox_total: (508, 508)
# zero_box:  (508, 508, 1)
# id:  20181201_19367983_num_2_class_0_img.tiff
# IoU:  0.825
# 0.904
# 0.825
# len(dice_seg_arr):  29
# len(dice_seg_arr):  29
# len(iou_seg_arr):  29
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181211_19069603_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181211_19069603_num_1_class_2_img.tiff
# IoU:  0.79
# 0.883
# 0.79
# len(dice_seg_arr):  30
# len(dice_seg_arr):  30
# len(iou_seg_arr):  30
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181211_19069603_num_2_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181211_19069603_num_2_class_1_img.tiff
# IoU:  0.707
# 0.828
# 0.707
# len(dice_seg_arr):  31
# len(dice_seg_arr):  31
# len(iou_seg_arr):  31
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181213_19244293_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181213_19244293_num_1_class_0_img.tiff
# IoU:  0.593
# 0.744
# 0.593
# len(dice_seg_arr):  32
# len(dice_seg_arr):  32
# len(iou_seg_arr):  32
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181213_19244293_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181213_19244293_num_2_class_0_img.tiff
# IoU:  0.625
# 0.769
# 0.625
# len(dice_seg_arr):  33
# len(dice_seg_arr):  33
# len(iou_seg_arr):  33
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181213_19244293_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181213_19244293_num_3_class_0_img.tiff
# IoU:  0.765
# 0.867
# 0.765
# len(dice_seg_arr):  34
# len(dice_seg_arr):  34
# len(iou_seg_arr):  34
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181213_19244293_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181213_19244293_num_4_class_0_img.tiff
# IoU:  0.744
# 0.853
# 0.744
# len(dice_seg_arr):  35
# len(dice_seg_arr):  35
# len(iou_seg_arr):  35
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181213_19244293_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181213_19244293_num_5_class_0_img.tiff
# IoU:  0.787
# 0.881
# 0.787
# len(dice_seg_arr):  36
# len(dice_seg_arr):  36
# len(iou_seg_arr):  36
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181218_40272423_num_1_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181218_40272423_num_1_class_1_img.tiff
# IoU:  0.777
# 0.874
# 0.777
# len(dice_seg_arr):  37
# len(dice_seg_arr):  37
# len(iou_seg_arr):  37
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181218_40272423_num_2_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181218_40272423_num_2_class_1_img.tiff
# IoU:  0.834
# 0.91
# 0.834
# len(dice_seg_arr):  38
# len(dice_seg_arr):  38
# len(iou_seg_arr):  38
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181218_40272423_num_3_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181218_40272423_num_3_class_1_img.tiff
# IoU:  0.793
# 0.885
# 0.793
# len(dice_seg_arr):  39
# len(dice_seg_arr):  39
# len(iou_seg_arr):  39
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181218_40272423_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181218_40272423_num_5_class_0_img1.tiff
# IoU:  -1
# Fail
# -1
# -1
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181218_40272423_num_5_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  40
# len(dice_seg_arr):  40
# len(iou_seg_arr):  40
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181220_29838583_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181220_29838583_num_1_class_0_img.tiff
# IoU:  0.067
# Fail
# 0.126
# 0.067
# len(dice_seg_arr):  41
# len(dice_seg_arr):  41
# len(iou_seg_arr):  41
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20181220_29838583_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20181220_29838583_num_2_class_0_img.tiff
# IoU:  0.345
# 0.513
# 0.345
# len(dice_seg_arr):  42
# len(dice_seg_arr):  42
# len(iou_seg_arr):  42
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190104_31185263_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190104_31185263_num_1_class_0_img.tiff
# IoU:  0.46
# 0.63
# 0.46
# len(dice_seg_arr):  43
# len(dice_seg_arr):  43
# len(iou_seg_arr):  43
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190104_31185263_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190104_31185263_num_2_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  44
# len(dice_seg_arr):  44
# len(iou_seg_arr):  44
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190104_31185263_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190104_31185263_num_3_class_0_img1.tiff
# IoU:  0.747
# 0.855
# 0.747
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190104_31185263_num_3_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  45
# len(dice_seg_arr):  45
# len(iou_seg_arr):  45
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190104_31185263_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190104_31185263_num_4_class_0_img.tiff
# IoU:  0.817
# 0.899
# 0.817
# len(dice_seg_arr):  46
# len(dice_seg_arr):  46
# len(iou_seg_arr):  46
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190114_18344593_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190114_18344593_num_1_class_0_img.tiff
# IoU:  0.923
# 0.96
# 0.923
# len(dice_seg_arr):  47
# len(dice_seg_arr):  47
# len(iou_seg_arr):  47
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190114_18344593_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190114_18344593_num_2_class_0_img.tiff
# IoU:  0.794
# 0.885
# 0.794
# len(dice_seg_arr):  48
# len(dice_seg_arr):  48
# len(iou_seg_arr):  48
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190114_18344593_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190114_18344593_num_3_class_0_img.tiff
# IoU:  0.905
# 0.95
# 0.905
# len(dice_seg_arr):  49
# len(dice_seg_arr):  49
# len(iou_seg_arr):  49
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190114_18344593_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190114_18344593_num_4_class_0_img.tiff
# IoU:  0.858
# 0.923
# 0.858
# len(dice_seg_arr):  50
# len(dice_seg_arr):  50
# len(iou_seg_arr):  50
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190114_18344593_num_5_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190114_18344593_num_5_class_0_img.tiff
# IoU:  0.799
# 0.888
# 0.799
# len(dice_seg_arr):  51
# len(dice_seg_arr):  51
# len(iou_seg_arr):  51
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_1_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_1_class_1_img1.tiff
# IoU:  0.547
# 0.707
# 0.547
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_1_class_1_img2.tiff
# IoU:  0.0
# Fail
# 0.0
# 0.0
# len(dice_seg_arr):  52
# len(dice_seg_arr):  52
# len(iou_seg_arr):  52
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_2_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_2_class_1_img1.tiff
# IoU:  0.667
# 0.8
# 0.667
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_2_class_1_img2.tiff
# IoU:  0.0
# Fail
# 0.0
# 0.0
# len(dice_seg_arr):  53
# len(dice_seg_arr):  53
# len(iou_seg_arr):  53
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_3_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_3_class_2_img.tiff
# IoU:  0.343
# 0.51
# 0.343
# len(dice_seg_arr):  54
# len(dice_seg_arr):  54
# len(iou_seg_arr):  54
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_4_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_4_class_2_img.tiff
# IoU:  0.867
# 0.929
# 0.867
# len(dice_seg_arr):  55
# len(dice_seg_arr):  55
# len(iou_seg_arr):  55
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_5_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_5_class_1_img1.tiff
# IoU:  0.621
# 0.766
# 0.621
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_5_class_1_img2.tiff
# IoU:  0.0
# Fail
# 0.0
# 0.0
# len(dice_seg_arr):  56
# len(dice_seg_arr):  56
# len(iou_seg_arr):  56
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190115_22020043_num_6_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_6_class_2_img1.tiff
# IoU:  0.281
# 0.438
# 0.281
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190115_22020043_num_6_class_2_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  57
# len(dice_seg_arr):  57
# len(iou_seg_arr):  57
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190118_19451383_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190118_19451383_num_1_class_0_img.tiff
# IoU:  0.516
# 0.681
# 0.516
# len(dice_seg_arr):  58
# len(dice_seg_arr):  58
# len(iou_seg_arr):  58
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190118_19451383_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190118_19451383_num_2_class_0_img.tiff
# IoU:  0.869
# 0.93
# 0.869
# len(dice_seg_arr):  59
# len(dice_seg_arr):  59
# len(iou_seg_arr):  59
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190118_19451383_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190118_19451383_num_3_class_0_img.tiff
# IoU:  0.273
# 0.428
# 0.273
# len(dice_seg_arr):  60
# len(dice_seg_arr):  60
# len(iou_seg_arr):  60
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190118_19451383_num_4_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190118_19451383_num_4_class_0_img1.tiff
# IoU:  0.054
# Fail
# 0.103
# 0.054
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190118_19451383_num_4_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  61
# len(dice_seg_arr):  61
# len(iou_seg_arr):  61
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190122_29234793_num_2_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190122_29234793_num_2_class_2_img.tiff
# IoU:  0.884
# 0.938
# 0.884
# len(dice_seg_arr):  62
# len(dice_seg_arr):  62
# len(iou_seg_arr):  62
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190122_29234793_num_3_class_1_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190122_29234793_num_3_class_1_img.tiff
# IoU:  0.605
# 0.754
# 0.605
# len(dice_seg_arr):  63
# len(dice_seg_arr):  63
# len(iou_seg_arr):  63
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190122_32639533_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190122_32639533_num_1_class_0_img.tiff
# IoU:  0.744
# 0.854
# 0.744
# len(dice_seg_arr):  64
# len(dice_seg_arr):  64
# len(iou_seg_arr):  64
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190201_40279176_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190201_40279176_num_1_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  65
# len(dice_seg_arr):  65
# len(iou_seg_arr):  65
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190201_40279176_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190201_40279176_num_2_class_0_img1.tiff
# IoU:  0.327
# 0.493
# 0.327
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190201_40279176_num_2_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  66
# len(dice_seg_arr):  66
# len(iou_seg_arr):  66
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190201_40279176_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190201_40279176_num_3_class_0_img.tiff
# IoU:  0.481
# 0.649
# 0.481
# len(dice_seg_arr):  67
# len(dice_seg_arr):  67
# len(iou_seg_arr):  67
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190218_40369055_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190218_40369055_num_1_class_0_img.tiff
# IoU:  0.785
# 0.88
# 0.785
# len(dice_seg_arr):  68
# len(dice_seg_arr):  68
# len(iou_seg_arr):  68
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190226_35209543_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190226_35209543_num_1_class_0_img.tiff
# IoU:  0.024
# Fail
# 0.047
# 0.024
# len(dice_seg_arr):  69
# len(dice_seg_arr):  69
# len(iou_seg_arr):  69
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190308_40409946_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190308_40409946_num_1_class_0_img1.tiff
# IoU:  0.381
# 0.552
# 0.381
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190308_40409946_num_1_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  70
# len(dice_seg_arr):  70
# len(iou_seg_arr):  70
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190321_40431525_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190321_40431525_num_1_class_0_img.tiff
# IoU:  0.884
# 0.938
# 0.884
# len(dice_seg_arr):  71
# len(dice_seg_arr):  71
# len(iou_seg_arr):  71
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190325_21811813_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190325_21811813_num_1_class_0_img1.tiff
# IoU:  -1
# Fail
# -1
# -1
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190325_21811813_num_1_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  72
# len(dice_seg_arr):  72
# len(iou_seg_arr):  72
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190325_21811813_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190325_21811813_num_2_class_0_img1.tiff
# IoU:  0.769
# 0.869
# 0.769
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190325_21811813_num_2_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  73
# len(dice_seg_arr):  73
# len(iou_seg_arr):  73
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190325_21811813_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190325_21811813_num_3_class_0_img.tiff
# IoU:  0.666
# 0.799
# 0.666
# len(dice_seg_arr):  74
# len(dice_seg_arr):  74
# len(iou_seg_arr):  74
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190326_9913693_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190326_9913693_num_1_class_0_img.tiff
# IoU:  0.607
# 0.756
# 0.607
# len(dice_seg_arr):  75
# len(dice_seg_arr):  75
# len(iou_seg_arr):  75
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190328_40446990_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190328_40446990_num_1_class_0_img.tiff
# IoU:  0.827
# 0.906
# 0.827
# len(dice_seg_arr):  76
# len(dice_seg_arr):  76
# len(iou_seg_arr):  76
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190328_40446990_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# 1.0
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190328_40446990_num_2_class_0_img1.tiff
# IoU:  0.857
# 0.923
# 0.857
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190328_40446990_num_2_class_0_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  77
# len(dice_seg_arr):  77
# len(iou_seg_arr):  77
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190329_17360553_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190329_17360553_num_1_class_0_img.tiff
# IoU:  0.809
# 0.894
# 0.809
# len(dice_seg_arr):  78
# len(dice_seg_arr):  78
# len(iou_seg_arr):  78
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190329_17360553_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190329_17360553_num_2_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# len(dice_seg_arr):  79
# len(dice_seg_arr):  79
# len(iou_seg_arr):  79
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190329_17360553_num_3_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190329_17360553_num_3_class_0_img.tiff
# IoU:  0.728
# 0.843
# 0.728
# len(dice_seg_arr):  80
# len(dice_seg_arr):  80
# len(iou_seg_arr):  80
# input_raw: 925
# label_raw: 925
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190329_40451156_num_1_class_0_img.tiff
# label_i.shape:  (925, 925)
# output_i.shape:  (512, 512)
# label_i.shape:  (925, 925)
# output_i.shape:  (925, 925)
# label_i.max:  255
# output_i.max:  255
# output_total:  (925, 925)
# output_bbox_total: (925, 925)
# zero_box:  (925, 925, 1)
# id:  20190329_40451156_num_1_class_0_img.tiff
# IoU:  0.867
# 0.929
# 0.867
# len(dice_seg_arr):  81
# len(dice_seg_arr):  81
# len(iou_seg_arr):  81
# input_raw: 925
# label_raw: 925
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190329_40451156_num_2_class_0_img.tiff
# label_i.shape:  (925, 925)
# output_i.shape:  (512, 512)
# label_i.shape:  (925, 925)
# output_i.shape:  (925, 925)
# label_i.max:  255
# output_i.max:  255
# output_total:  (925, 925)
# output_bbox_total: (925, 925)
# zero_box:  (925, 925, 1)
# id:  20190329_40451156_num_2_class_0_img.tiff
# IoU:  0.766
# 0.868
# 0.766
# len(dice_seg_arr):  82
# len(dice_seg_arr):  82
# len(iou_seg_arr):  82
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190408_28763963_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190408_28763963_num_1_class_0_img.tiff
# IoU:  0.733
# 0.846
# 0.733
# len(dice_seg_arr):  83
# len(dice_seg_arr):  83
# len(iou_seg_arr):  83
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190412_34426593_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190412_34426593_num_1_class_0_img.tiff
# IoU:  0.692
# 0.818
# 0.692
# len(dice_seg_arr):  84
# len(dice_seg_arr):  84
# len(iou_seg_arr):  84
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190412_34426593_num_2_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190412_34426593_num_2_class_0_img.tiff
# IoU:  0.913
# 0.954
# 0.913
# len(dice_seg_arr):  85
# len(dice_seg_arr):  85
# len(iou_seg_arr):  85
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190422_40430003_num_1_class_0_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20190422_40430003_num_1_class_0_img.tiff
# IoU:  0.69
# 0.817
# 0.69
# len(dice_seg_arr):  86
# len(dice_seg_arr):  86
# len(iou_seg_arr):  86
# input_raw: 1023
# label_raw: 1023
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190429_24807963_num_1_class_0_img.tiff
# label_i.shape:  (1023, 1023)
# output_i.shape:  (512, 512)
# label_i.shape:  (1023, 1023)
# output_i.shape:  (1023, 1023)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1023, 1023)
# output_bbox_total: (1023, 1023)
# zero_box:  (1023, 1023, 1)
# id:  20190429_24807963_num_1_class_0_img.tiff
# IoU:  0.684
# 0.812
# 0.684
# len(dice_seg_arr):  87
# len(dice_seg_arr):  87
# len(iou_seg_arr):  87
# input_raw: 792
# label_raw: 792
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190429_25441943_num_1_class_0_img.tiff
# label_i.shape:  (792, 792)
# output_i.shape:  (512, 512)
# label_i.shape:  (792, 792)
# output_i.shape:  (792, 792)
# label_i.max:  255
# output_i.max:  255
# output_total:  (792, 792)
# output_bbox_total: (792, 792)
# zero_box:  (792, 792, 1)
# id:  20190429_25441943_num_1_class_0_img.tiff
# IoU:  0.845
# 0.916
# 0.845
# len(dice_seg_arr):  88
# len(dice_seg_arr):  88
# len(iou_seg_arr):  88
# input_raw: 792
# label_raw: 792
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190429_25441943_num_2_class_0_img.tiff
# label_i.shape:  (792, 792)
# output_i.shape:  (512, 512)
# label_i.shape:  (792, 792)
# output_i.shape:  (792, 792)
# label_i.max:  255
# output_i.max:  255
# output_total:  (792, 792)
# output_bbox_total: (792, 792)
# zero_box:  (792, 792, 1)
# id:  20190429_25441943_num_2_class_0_img.tiff
# IoU:  0.814
# 0.898
# 0.814
# len(dice_seg_arr):  89
# len(dice_seg_arr):  89
# len(iou_seg_arr):  89
# input_raw: 792
# label_raw: 792
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20190429_25441943_num_3_class_0_img.tiff
# label_i.shape:  (792, 792)
# output_i.shape:  (512, 512)
# label_i.shape:  (792, 792)
# output_i.shape:  (792, 792)
# label_i.max:  255
# output_i.max:  255
# output_total:  (792, 792)
# output_bbox_total: (792, 792)
# zero_box:  (792, 792, 1)
# id:  20190429_25441943_num_3_class_0_img.tiff
# IoU:  -1
# Fail
# -1
# -1
# ...
# False Positive
# -1
# -1
# len(dice_seg_arr):  1388
# len(dice_seg_arr):  1388
# len(iou_seg_arr):  1388
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210305_19215973_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210305_19215973_num_1_class_2_img.tiff
# IoU:  0.837
# 0.911
# 0.837
# len(dice_seg_arr):  1389
# len(dice_seg_arr):  1389
# len(iou_seg_arr):  1389
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210311_19456113_num_2_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210311_19456113_num_2_class_2_img.tiff
# IoU:  0.84
# 0.913
# 0.84
# len(dice_seg_arr):  1390
# len(dice_seg_arr):  1390
# len(iou_seg_arr):  1390
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_25914683_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_25914683_num_1_class_2_img.tiff
# IoU:  0.811
# 0.896
# 0.811
# len(dice_seg_arr):  1391
# len(dice_seg_arr):  1391
# len(iou_seg_arr):  1391
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_25914683_num_2_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_25914683_num_2_class_2_img.tiff
# IoU:  0.925
# 0.961
# 0.925
# len(dice_seg_arr):  1392
# len(dice_seg_arr):  1392
# len(iou_seg_arr):  1392
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_25914683_num_3_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_25914683_num_3_class_2_img.tiff
# IoU:  0.946
# 0.972
# 0.946
# len(dice_seg_arr):  1393
# len(dice_seg_arr):  1393
# len(iou_seg_arr):  1393
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_25914683_num_4_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_25914683_num_4_class_2_img.tiff
# IoU:  0.758
# 0.863
# 0.758
# len(dice_seg_arr):  1394
# len(dice_seg_arr):  1394
# len(iou_seg_arr):  1394
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_25914683_num_5_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_25914683_num_5_class_2_img.tiff
# IoU:  0.859
# 0.924
# 0.859
# len(dice_seg_arr):  1395
# len(dice_seg_arr):  1395
# len(iou_seg_arr):  1395
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210312_9132533_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210312_9132533_num_1_class_2_img.tiff
# IoU:  0.857
# 0.923
# 0.857
# len(dice_seg_arr):  1396
# len(dice_seg_arr):  1396
# len(iou_seg_arr):  1396
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210319_3368523_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210319_3368523_num_1_class_2_img.tiff
# IoU:  0.903
# 0.949
# 0.903
# len(dice_seg_arr):  1397
# len(dice_seg_arr):  1397
# len(iou_seg_arr):  1397
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210319_3368523_num_3_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210319_3368523_num_3_class_2_img1.tiff
# IoU:  0.89
# 0.942
# 0.89
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210319_3368523_num_3_class_2_img2.tiff
# IoU:  0.0
# Fail
# 0.0
# 0.0
# len(dice_seg_arr):  1398
# len(dice_seg_arr):  1398
# len(iou_seg_arr):  1398
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210323_41183292_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210323_41183292_num_1_class_2_img1.tiff
# IoU:  0.034
# Fail
# 0.066
# 0.034
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210323_41183292_num_1_class_2_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  1399
# len(dice_seg_arr):  1399
# len(iou_seg_arr):  1399
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210323_41183292_num_2_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210323_41183292_num_2_class_2_img.tiff
# IoU:  0.583
# 0.736
# 0.583
# len(dice_seg_arr):  1400
# len(dice_seg_arr):  1400
# len(iou_seg_arr):  1400
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210326_35696743_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210326_35696743_num_1_class_2_img.tiff
# IoU:  0.955
# 0.977
# 0.955
# len(dice_seg_arr):  1401
# len(dice_seg_arr):  1401
# len(iou_seg_arr):  1401
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210326_35696743_num_2_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210326_35696743_num_2_class_2_img.tiff
# IoU:  0.88
# 0.936
# 0.88
# len(dice_seg_arr):  1402
# len(dice_seg_arr):  1402
# len(iou_seg_arr):  1402
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210326_4828633_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210326_4828633_num_1_class_2_img.tiff
# IoU:  0.535
# 0.697
# 0.535
# len(dice_seg_arr):  1403
# len(dice_seg_arr):  1403
# len(iou_seg_arr):  1403
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210330_10417333_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210330_10417333_num_1_class_2_img1.tiff
# IoU:  0.497
# 0.664
# 0.497
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210330_10417333_num_1_class_2_img2.tiff
# False Positive
# -1
# -1
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210330_10417333_num_1_class_2_img3.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  1404
# len(dice_seg_arr):  1404
# len(iou_seg_arr):  1404
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210331_16797253_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210331_16797253_num_1_class_2_img.tiff
# IoU:  0.738
# 0.849
# 0.738
# len(dice_seg_arr):  1405
# len(dice_seg_arr):  1405
# len(iou_seg_arr):  1405
# input_raw: 1183
# label_raw: 1183
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210401_7437253_num_1_class_2_img.tiff
# label_i.shape:  (1183, 1183)
# output_i.shape:  (512, 512)
# label_i.shape:  (1183, 1183)
# output_i.shape:  (1183, 1183)
# label_i.max:  255
# output_i.max:  255
# 1.0
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210401_7437253_num_1_class_2_img1.tiff
# IoU:  0.788
# 0.881
# 0.788
# output_total:  (1183, 1183)
# output_bbox_total: (1183, 1183)
# zero_box:  (1183, 1183, 1)
# id:  20210401_7437253_num_1_class_2_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  1406
# len(dice_seg_arr):  1406
# len(iou_seg_arr):  1406
# input_raw: 996
# label_raw: 996
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210402_14574073_num_1_class_2_img.tiff
# label_i.shape:  (996, 996)
# output_i.shape:  (512, 512)
# label_i.shape:  (996, 996)
# output_i.shape:  (996, 996)
# label_i.max:  255
# output_i.max:  255
# 0.0
# output_total:  (996, 996)
# output_bbox_total: (996, 996)
# zero_box:  (996, 996, 1)
# id:  20210402_14574073_num_1_class_2_img1.tiff
# IoU:  0.773
# 0.872
# 0.773
# output_total:  (996, 996)
# output_bbox_total: (996, 996)
# zero_box:  (996, 996, 1)
# id:  20210402_14574073_num_1_class_2_img2.tiff
# False Positive
# -1
# -1
# len(dice_seg_arr):  1407
# len(dice_seg_arr):  1407
# len(iou_seg_arr):  1407
# input_raw: 996
# label_raw: 996
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210402_14574073_num_2_class_2_img.tiff
# label_i.shape:  (996, 996)
# output_i.shape:  (512, 512)
# label_i.shape:  (996, 996)
# output_i.shape:  (996, 996)
# label_i.max:  255
# output_i.max:  255
# output_total:  (996, 996)
# output_bbox_total: (996, 996)
# zero_box:  (996, 996, 1)
# id:  20210402_14574073_num_2_class_2_img.tiff
# IoU:  0.813
# 0.897
# 0.813
# len(dice_seg_arr):  1408
# len(dice_seg_arr):  1408
# len(iou_seg_arr):  1408
# input_raw: 1000
# label_raw: 1000
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210405_11783153_num_1_class_2_img.tiff
# label_i.shape:  (1000, 1000)
# output_i.shape:  (512, 512)
# label_i.shape:  (1000, 1000)
# output_i.shape:  (1000, 1000)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1000, 1000)
# output_bbox_total: (1000, 1000)
# zero_box:  (1000, 1000, 1)
# id:  20210405_11783153_num_1_class_2_img.tiff
# IoU:  0.641
# 0.781
# 0.641
# len(dice_seg_arr):  1409
# len(dice_seg_arr):  1409
# len(iou_seg_arr):  1409
# input_raw: 1000
# label_raw: 1000
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210405_11783153_num_2_class_2_img.tiff
# label_i.shape:  (1000, 1000)
# output_i.shape:  (512, 512)
# label_i.shape:  (1000, 1000)
# output_i.shape:  (1000, 1000)
# label_i.max:  255
# output_i.max:  255
# output_total:  (1000, 1000)
# output_bbox_total: (1000, 1000)
# zero_box:  (1000, 1000, 1)
# id:  20210405_11783153_num_2_class_2_img.tiff
# IoU:  0.772
# 0.871
# 0.772
# len(dice_seg_arr):  1410
# len(dice_seg_arr):  1410
# len(iou_seg_arr):  1410
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210706_21064483_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210706_21064483_num_1_class_2_img.tiff
# IoU:  0.934
# 0.966
# 0.934
# len(dice_seg_arr):  1411
# len(dice_seg_arr):  1411
# len(iou_seg_arr):  1411
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210706_21064483_num_2_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210706_21064483_num_2_class_2_img.tiff
# IoU:  0.947
# 0.973
# 0.947
# len(dice_seg_arr):  1412
# len(dice_seg_arr):  1412
# len(iou_seg_arr):  1412
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210706_21064483_num_3_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210706_21064483_num_3_class_2_img.tiff
# IoU:  0.866
# 0.928
# 0.866
# len(dice_seg_arr):  1413
# len(dice_seg_arr):  1413
# len(iou_seg_arr):  1413
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210706_21064483_num_4_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210706_21064483_num_4_class_2_img.tiff
# IoU:  0.846
# 0.917
# 0.846
# len(dice_seg_arr):  1414
# len(dice_seg_arr):  1414
# len(iou_seg_arr):  1414
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210716_14566433_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210716_14566433_num_1_class_2_img.tiff
# IoU:  0.874
# 0.932
# 0.874
# len(dice_seg_arr):  1415
# len(dice_seg_arr):  1415
# len(iou_seg_arr):  1415
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20210716_14566433_num_2_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20210716_14566433_num_2_class_2_img.tiff
# IoU:  0.889
# 0.941
# 0.889
# len(dice_seg_arr):  1416
# len(dice_seg_arr):  1416
# len(iou_seg_arr):  1416
# input_raw: 851
# label_raw: 851
# input: 512
# label: 512
# step 2 --------------------------------
# ID:  20211005_17104253_num_1_class_2_img.tiff
# label_i.shape:  (851, 851)
# output_i.shape:  (512, 512)
# label_i.shape:  (851, 851)
# output_i.shape:  (851, 851)
# label_i.max:  255
# output_i.max:  255
# output_total:  (851, 851)
# output_bbox_total: (851, 851)
# zero_box:  (851, 851, 1)
# id:  20211005_17104253_num_1_class_2_img.tiff
# IoU:  0.851
# 0.92
# 0.851
# len(dice_seg_arr):  1417
# len(dice_seg_arr):  1417
# len(iou_seg_arr):  1417

# %%
path1 = './result/20220320_segmentation/result/test/Results_Detection_all_1.csv'
path2 = './result/20220320_segmentation/result/test/Results_Detection_all_2.csv'
path3 = './result/20220320_segmentation/result/test/Results_Detection_all_3.csv'
path4 = './result/20220320_segmentation/result/test/Results_Detection_all_4.csv'
path5 = './result/20220320_segmentation/result/test/Results_Detection_all_5.csv'

# %%
df1 = pd.read_csv(path1)
df1_TP_FN = df1[df1['IoU_detect'] >= -1]
df1_FP = df1[df1['IoU_detect'] < 0]
df1_box_IoU = df1['IoU_detect'].replace([-1,-2],[0,0])

df2 = pd.read_csv(path2)
df2_TP_FN = df2[df2['IoU_detect'] >=-1]
df2_FP = df2[df2['IoU_detect'] < 0]
df2_box_IoU = df2['IoU_detect'].replace([-1,-2],[0,0])

df3 = pd.read_csv(path3)
df3_TP_FN = df3[df3['IoU_detect'] >=-1]
df3_FP = df3[df3['IoU_detect'] < 0]
df3_box_IoU = df3['IoU_detect'].replace([-1,-2],[0,0])

df4 = pd.read_csv(path4)
df4_TP_FN = df4[df4['IoU_detect'] >=-1]
df4_FP = df4[df4['IoU_detect'] < 0]
df4_box_IoU = df4['IoU_detect'].replace([-1,-2],[0,0])

df5 = pd.read_csv(path5)
df5_TP_FN = df5[df5['IoU_detect'] >= -1]
df5_FP = df5[df5['IoU_detect'] < 0]
df5_box_IoU = df5['IoU_detect'].replace([-1,-2],[0,0])

df_all = pd.concat([df1,df2,df3,df4,df5],axis = 0)
df_all_TP_FN = df_all[df_all['IoU_detect'] >= -1]
df_all_FP = df_all[df_all['IoU_detect'] < 0]
df_all_box_IoU = df_all['IoU_detect'].replace([-1,-2],[0,0])

# %%
from math import sqrt

def ci(score, y_true, positive=1):
    #y_true = np.array((y_true)).astype('int')
    #AUC = roc_auc_score(y_true, y_score,multi_class='ovr')

    
    N1 = sum(y_true == positive)
    N2 = sum(y_true != positive)
    Q1 = score / (2 - score)
    Q2 = 2*score**2 / (1 + score)
    SE_score = sqrt((score*(1 - score) + (N1 - 1)*(Q1 - score**2) + (N2 - 1)*(Q2 - score**2)) / (N1*N2))
    lower = score - 1.96*SE_score
    upper = score + 1.96*SE_score
    if lower < 0:
        lower = 0
    if upper > 1:
        upper = 1
    return lower, upper

# %%
def cal_detection_rate(df, L, CV):
    DC = df['IoU_detect'][df['IoU_detect'] > 0].copy()
    DC[DC >= 0.2] = 1
    DC[DC< 0.2] = 0
    DR= np.round(len(DC[DC>= 0.2])/ L,3)
    lower, upper = ci(DR,DC)
    print('Detection rate of '+CV+' : %.3f(%.3f-%.3f)' %(DR, lower,  upper))

# %%
def cal_FP_rate(df, L, CV):
    
    FC = df['IoU_detect'].copy()
    FC[FC >= 0] = 0
    FC[FC < 0] = 1
    

    FR= np.round(len(df[df['IoU_detect']<0])/ L,3)

    lower, upper = ci(FR,FC)
    print('False Positive Rate of '+CV+' : %.3f(%.3f-%.3f)' %(FR, lower,  upper))

# %%
cal_detection_rate(df1_TP_FN, 1468, 'CV1')
cal_detection_rate(df2_TP_FN, 1123, 'CV2')
cal_detection_rate(df3_TP_FN, 1294, 'CV3')
cal_detection_rate(df4_TP_FN, 1503, 'CV4')
cal_detection_rate(df5_TP_FN, 1434, 'CV5')
cal_detection_rate(df_all_TP_FN, (1123+1294+1503+1434+1468), 'all')
# Out:
# Detection rate of CV1 : 0.866(0.836-0.896)
# Detection rate of CV2 : 0.876(0.845-0.907)
# Detection rate of CV3 : 0.903(0.878-0.928)
# Detection rate of CV4 : 0.882(0.856-0.908)
# Detection rate of CV5 : 0.920(0.897-0.943)
# Detection rate of all : 0.889(0.877-0.901)

# %%
print('False Positive Rate')

cal_FP_rate(df1,1437, 'CV1')
cal_FP_rate(df2,1104, 'CV2')
cal_FP_rate(df3,1275, 'CV3')
cal_FP_rate(df4,1479, 'CV4')
cal_FP_rate(df5,1417, 'CV5')
cal_FP_rate(df_all,(1437+1104+1275+1479+1417), 'all')
# Out:
# False Positive Rate
# False Positive Rate of CV1 : 0.241(0.216-0.266)
# False Positive Rate of CV2 : 0.206(0.179-0.233)
# False Positive Rate of CV3 : 0.177(0.153-0.201)
# False Positive Rate of CV4 : 0.174(0.152-0.196)
# False Positive Rate of CV5 : 0.162(0.140-0.184)
# False Positive Rate of all : 0.192(0.181-0.203)

# %%
path1 = './result/20220320_segmentation/result/test/Results_Segmentation_all_1.csv'
path2 = './result/20220320_segmentation/result/test/Results_Segmentation_all_2.csv'
path3 = './result/20220320_segmentation/result/test/Results_Segmentation_all_3.csv'
path4 = './result/20220320_segmentation/result/test/Results_Segmentation_all_4.csv'
path5 = './result/20220320_segmentation/result/test/Results_Segmentation_all_5.csv'
df1 = pd.read_csv(path1)

# %%
df1 = pd.read_csv(path1)
df1_IoU = df1['IoU_seg'] 
df1_DSC = df1['DSC_seg'] 

df2 = pd.read_csv(path2)
df2_IoU = df2['IoU_seg'  ] 
df2_DSC = df2['DSC_seg'] 

df3 = pd.read_csv(path3)
df3_IoU = df3['IoU_seg'] 
df3_DSC = df3['DSC_seg'] 

df4 = pd.read_csv(path4)
df4_IoU = df4['IoU_seg'] 
df4_DSC = df4['DSC_seg'] 

df5 = pd.read_csv(path5)
df5_IoU = df5['IoU_seg'] 
df5_DSC = df5['DSC_seg'] 

df_all = pd.concat([df1,df2,df3,df4,df5],axis = 0)
df_all_IoU = df_all['IoU_seg'] 
df_all_DSC = df_all['DSC_seg']

# %%
df_all.to_csv('./result/20220320_segmentation/result/test/Results_Segmentation_all_total.csv',index=None)

# %%
print(np.round(np.mean(df1_IoU),3))
print(np.round(np.std(df1_IoU),3))
print('-'*30)
print(np.round(np.mean(df2_IoU),3))
print(np.round(np.std(df2_IoU),3))
print('-'*30)
print(np.round(np.mean(df3_IoU),3))
print(np.round(np.std(df3_IoU),3))
print('-'*30)
print(np.round(np.mean(df4_IoU),3))
print(np.round(np.std(df4_IoU),3))
print('-'*30)
print(np.round(np.mean(df5_IoU),3))
print(np.round(np.std(df5_IoU),3))
print('-'*30)
print(np.round(np.mean(df_all_IoU),3))
print(np.round(np.std(df_all_IoU),3))
print('-'*30)
# Out:
# 0.608
# 0.283
# ------------------------------
# 0.616
# 0.274
# ------------------------------
# 0.64
# 0.258
# ------------------------------
# 0.622
# 0.276
# ------------------------------
# 0.655
# 0.249
# ------------------------------
# 0.629
# 0.269
# ------------------------------

# %%
print(np.round(np.mean(df1_DSC),3))
print(np.round(np.std(df1_DSC),3))
print('-'*30)
print(np.round(np.mean(df2_DSC),3))
print(np.round(np.std(df2_DSC),3))
print('-'*30)
print(np.round(np.mean(df3_DSC),3))
print(np.round(np.std(df3_DSC),3))
print('-'*30)
print(np.round(np.mean(df4_DSC),3))
print(np.round(np.std(df4_DSC),3))
print('-'*30)
print(np.round(np.mean(df5_DSC),3))
print(np.round(np.std(df5_DSC),3))
print('-'*30)
print(np.round(np.mean(df_all_DSC),3))
print(np.round(np.std(df_all_DSC),3))
print('-'*30)
# Out:
# 0.706
# 0.29
# ------------------------------
# 0.716
# 0.278
# ------------------------------
# 0.74
# 0.259
# ------------------------------
# 0.72
# 0.28
# ------------------------------
# 0.755
# 0.246
# ------------------------------
# 0.728
# 0.272
# ------------------------------

# %%
os.chdir('/home/ubuntu/gcubme_ai/Workspace/S_Oh/US_Liver')

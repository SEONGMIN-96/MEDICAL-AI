# %%
import os
import sys
import glob
import shutil
import numpy as np
import pandas as pd
import tqdm

import time
import datetime

import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import tensorflow_addons as tfa
# import tensorflow_datasets as tfds

# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# 2023-11-08 04:02:29.317613: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2

# %% [markdown]
# ### Now time

# %%
# now_time
d = datetime.datetime.now()
now_time = f"{d.year}-{d.month}-{d.day}-{d.hour}-{d.minute}-{d.second}"

now_time_path = os.path.join("..", "exp", now_time)

if not os.path.exists(now_time_path):
    os.mkdir(now_time_path)
    os.mkdir(os.path.join(now_time_path, "save_img"))
    os.mkdir(os.path.join(now_time_path, "model_checkpoints"))

# %% [markdown]
# ### Dateload

# %%
# dataload
base_path = os.path.join("..", "data", "01_NBI")

# nbi data load
nbi_cancer_path = glob.glob(os.path.join(base_path, "nbi", "00_cancer", "*.jpg"))
nbi_ulcer_path = glob.glob(os.path.join(base_path, "nbi", "01_ulcer", "*.jpg"))
nbi_normal_path = glob.glob(os.path.join(base_path, "nbi", "02_normal", "*.jpg"))
nbi_adenoma_path = glob.glob(os.path.join(base_path, "nbi", "03_adenoma", "*.jpg"))

print("number of nbi 00_cancer paths:", len(nbi_cancer_path))
print("number of nbi 01_ulcer paths:", len(nbi_ulcer_path))
print("number of nbi 02_normal paths:", len(nbi_normal_path))
print("number of nbi 03_adenoma paths:", len(nbi_adenoma_path))
print("number of nbi total paths:", len(nbi_cancer_path)+len(nbi_ulcer_path)+len(nbi_normal_path)+len(nbi_adenoma_path))

# original data load
ori_cancer_path = glob.glob(os.path.join(base_path, "ori", "00_cancer", "*.jpg"))
ori_ulcer_path = glob.glob(os.path.join(base_path, "ori", "01_ulcer", "*.jpg"))
ori_normal_path = glob.glob(os.path.join(base_path, "ori", "02_normal", "*.jpg"))
ori_adenoma_path = glob.glob(os.path.join(base_path, "ori", "03_adenoma", "*.jpg"))

print("number of ori 00_cancer paths:", len(ori_cancer_path))
print("number of ori 01_ulcer paths:", len(ori_ulcer_path))
print("number of ori 02_normal paths:", len(ori_normal_path))
print("number of ori 03_adenoma paths:", len(ori_adenoma_path))
print("number of ori total paths:", len(ori_cancer_path)+len(ori_ulcer_path)+len(ori_normal_path)+len(ori_adenoma_path))
# Out:
# number of nbi 00_cancer paths: 579
# number of nbi 01_ulcer paths: 74
# number of nbi 02_normal paths: 300
# number of nbi 03_adenoma paths: 1175
# number of nbi total paths: 2128
# number of ori 00_cancer paths: 1307
# number of ori 01_ulcer paths: 266
# number of ori 02_normal paths: 5187
# number of ori 03_adenoma paths: 2066
# number of ori total paths: 8826

# %% [markdown]
# ### Prepare Sample dataset

# %%
def train_split(path_box, alpha, beta):
    return path_box[:int(len(path_box)*0.8)]

def test_split(path_box, alpha, beta):
    return path_box[int(len(path_box)*0.8):]


train_nbi_cancer_path = train_split(nbi_cancer_path)
train_nbi_ulcer_path = train_split(nbi_ulcer_path)
train_nbi_normal_path = train_split(nbi_normal_path)
train_nbi_adenoma_path = train_split(nbi_adenoma_path)

train_ori_cancer_path = train_split(ori_cancer_path)
train_ori_ulcer_path = train_split(ori_ulcer_path)
train_ori_normal_path = train_split(ori_normal_path)
train_ori_adenoma_path = train_split(ori_adenoma_path)

train_nbi_paths = train_nbi_cancer_path+train_nbi_ulcer_path+train_nbi_normal_path+train_nbi_adenoma_path
train_ori_paths = train_ori_cancer_path+train_ori_ulcer_path+train_ori_normal_path+train_ori_adenoma_path

test_nbi_cancer_path = test_split(nbi_cancer_path)
test_nbi_ulcer_path = test_split(nbi_ulcer_path)
test_nbi_normal_path = test_split(nbi_normal_path)
test_nbi_adenoma_path = test_split(nbi_adenoma_path)

test_ori_cancer_path = test_split(ori_cancer_path)
test_ori_ulcer_path = test_split(ori_ulcer_path)
test_ori_normal_path = test_split(ori_normal_path)
test_ori_adenoma_path = test_split(ori_adenoma_path)

test_nbi_paths = test_nbi_cancer_path+test_nbi_ulcer_path+test_nbi_normal_path+test_nbi_adenoma_path
test_ori_paths = test_ori_cancer_path+test_ori_ulcer_path+test_ori_normal_path+test_ori_adenoma_path


train_ori_imgs = np.array([mpimg.imread(path) for path in train_ori_paths])
train_nbi_imgs = np.array([mpimg.imread(path) for path in train_nbi_paths])

test_ori_imgs = np.array([mpimg.imread(path) for path in test_ori_paths])
test_nbi_imgs = np.array([mpimg.imread(path) for path in test_nbi_paths])

print("number of train ori_imgs:", len(train_ori_imgs))
print("number of train nbi_imgs:", len(train_nbi_imgs))
print("number of test ori_imgs:", len(test_ori_imgs))
print("number of test nbi_imgs:", len(test_nbi_imgs))
# Out:
# /root/anaconda3/envs/nipa/lib/python3.7/site-packages/ipykernel_launcher.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /root/anaconda3/envs/nipa/lib/python3.7/site-packages/ipykernel_launcher.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /root/anaconda3/envs/nipa/lib/python3.7/site-packages/ipykernel_launcher.py:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# number of train ori_imgs: 7058
# number of train nbi_imgs: 1702
# number of test ori_imgs: 1768
# number of test nbi_imgs: 426
# /root/anaconda3/envs/nipa/lib/python3.7/site-packages/ipykernel_launcher.py:39: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ### Prepare the dataset

# %%
# Define the standard image size.
# orig_img_size = (286, 286)
orig_img_size = (1144, 1144)
# Size of the random crops to be used during training.
# input_img_size = (256, 256, 3)
input_img_size = (1024, 1024, 3)
# Weights initializer for the layers.
kernel_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
# Gamma initializer for instance normalization.
gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

buffer_size = 256
batch_size = 1


def normalize_img(img):
    img = tf.cast(img, dtype=tf.float32)
    # Map values in the range [-1, 1]
    return (img / 127.5) - 1.0


def preprocess_train_image(img):
    # Random flip
    img = tf.image.random_flip_left_right(img)
    # Resize to the original size first
    img = tf.image.resize(img, [*orig_img_size])
    # Random crop to 256X256
    img = tf.image.random_crop(img, size=[*input_img_size])
    # Normalize the pixel values in the range [-1, 1]
    img = normalize_img(img)
    # if want batch_size 1, do expand dim
    if batch_size == 1:
        img = tf.expand_dims(img, axis=0)
    return img


def preprocess_test_image(img):
    
    # Only resizing and normalization for the test images.
    img = tf.image.resize(img, [input_img_size[0], input_img_size[1]])
    img = normalize_img(img)
    if batch_size == 1:
        img = tf.expand_dims(img, axis=0)
    return img

# %% [markdown]
# ### Create Dataset object

# %%
# Apply the preprocessing operations to the training data
train_ori = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, train_ori_imgs))))
train_nbi = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, train_nbi_imgs))))

if batch_size != 1:
    train_ori = train_ori.shuffle(buffer_size=buffer_size)
    train_ori = train_ori.batch(batch_size)

    train_nbi = train_nbi.shuffle(buffer_size=buffer_size)
    train_nbi = train_nbi.batch(batch_size)

# Apply the preprocessing operations to the test data
test_ori = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, test_ori_imgs))))
test_nbi = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, test_nbi_imgs))))

if batch_size != 1:
    test_ori = test_ori.shuffle(buffer_size=buffer_size)
    test_ori = test_ori.batch(batch_size)

    test_nbi = test_nbi.shuffle(buffer_size=buffer_size)
    test_nbi = test_nbi.batch(batch_size)
# Out:
# 2023-11-08 04:11:13.806773: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-11-08 04:11:13.810488: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-11-08 04:11:13.855427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0004:04:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:13.857569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0004:05:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:13.859703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0035:03:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:13.861830: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0035:04:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:13.861855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2023-11-08 04:11:13.862789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-11-08 04:11:13.862824: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-11-08 04:11:13.863727: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-11-08 04:11:13.863940: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-11-08 04:11:13.864938: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-11-08 04:11:13.865756: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-11-08 04:11:13.869215: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-11-08 04:11:13.887027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2023-11-08 04:11:13.943783: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-11-08 04:11:14.501154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0004:04:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:14.503357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0004:05:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:14.505548: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0035:03:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:14.507726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0035:04:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.50GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-11-08 04:11:14.507779: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2023-11-08 04:11:14.507807: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-11-08 04:11:14.507828: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-11-08 04:11:14.507850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-11-08 04:11:14.507872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-11-08 04:11:14.507894: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-11-08 04:11:14.507915: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-11-08 04:11:14.507937: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-11-08 04:11:14.525160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2023-11-08 04:11:14.525192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2023-11-08 04:11:16.347154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-11-08 04:11:16.347203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2023-11-08 04:11:16.347214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y Y Y
# 2023-11-08 04:11:16.347222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N Y Y
# 2023-11-08 04:11:16.347230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   Y Y N Y
# 2023-11-08 04:11:16.347237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   Y Y Y N
# 2023-11-08 04:11:16.362161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30156 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0004:04:00.0, compute capability: 7.0)
# 2023-11-08 04:11:16.367541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 30156 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0004:05:00.0, compute capability: 7.0)
# 2023-11-08 04:11:16.371944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 30156 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0035:03:00.0, compute capability: 7.0)
# 2023-11-08 04:11:16.377586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 30156 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0035:04:00.0, compute capability: 7.0)
# 2023-11-08 04:11:59.145183: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 14.98MiB (rounded to 15704832)requested by op Squeeze
# Current allocation summary follows.
# 2023-11-08 04:11:59.145244: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2023-11-08 04:11:59.145267: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 3, Chunks in use: 3. 768B allocated for chunks. 768B in use in bin. 12B client-requested in use in bin.
# 2023-11-08 04:11:59.145286: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145308: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2023-11-08 04:11:59.145327: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145360: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145396: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145428: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145455: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145480: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145507: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145538: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145582: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145623: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145679: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 3.41MiB allocated for chunks. 3.41MiB in use in bin. 3.41MiB client-requested in use in bin.
# 2023-11-08 04:11:59.145725: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145761: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 2510, Chunks in use: 2508. 29.41GiB allocated for chunks. 29.39GiB in use in bin. 29.39GiB client-requested in use in bin.
# 2023-11-08 04:11:59.145794: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 36.02MiB allocated for chunks. 36.02MiB in use in bin. 24.00MiB client-requested in use in bin.
# 2023-11-08 04:11:59.145824: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145853: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145882: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145910: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-08 04:11:59.145938: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 14.98MiB was 8.00MiB, Chunk State:
# 2023-11-08 04:11:59.145975: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 8.59MiB | Requested Size: 4B | in_use: 0 | bin_num: 15, prev:   Size: 3.41MiB | Requested Size: 3.41MiB | in_use: 1 | bin_num: -1, next:   Size: 17.44MiB | Requested Size: 12.00MiB | in_use: 1 | bin_num: -1
# 2023-11-08 04:11:59.146019: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 12.00MiB | Requested Size: 12.00MiB | in_use: 0 | bin_num: 15, prev:   Size: 12.00MiB | Requested Size: 12.00MiB | in_use: 1 | bin_num: -1, next:   Size: 12.00MiB | Requested Size: 12.00MiB | in_use: 1 | bin_num: -1
# 2023-11-08 04:11:59.146057: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 31620881408
# 2023-11-08 04:11:59.146098: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0000000 of size 1280 next 1
# 2023-11-08 04:11:59.146131: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0000500 of size 256 next 2
# 2023-11-08 04:11:59.146165: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0000600 of size 256 next 3
# 2023-11-08 04:11:59.146195: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0000700 of size 256 next 4
# 2023-11-08 04:11:59.146222: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0000800 of size 3575296 next 2517
# 2023-11-08 04:11:59.146239: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7094e0369600 of size 9007616 next 5
# 2023-11-08 04:11:59.146255: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e0c00800 of size 18288896 next 6
# 2023-11-08 04:11:59.146287: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e1d71900 of size 12582912 next 7
# 2023-11-08 04:11:59.146322: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7094e2971900 of size 12582912 next 9
# 2023-11-08 04:11:59.146353: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e3571900 of size 12582912 next 10
# 2023-11-08 04:11:59.146385: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e4171900 of size 12582912 next 8
# 2023-11-08 04:11:59.146409: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e4d71900 of size 12582912 next 13
# 2023-11-08 04:11:59.146430: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e5971900 of size 12582912 next 14
# 2023-11-08 04:11:59.146452: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e6571900 of size 12582912 next 15
# 2023-11-08 04:11:59.146474: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e7171900 of size 12582912 next 11
# 2023-11-08 04:11:59.146492: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e7d71900 of size 12582912 next 17
# 2023-11-08 04:11:59.146527: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e8971900 of size 12582912 next 12
# 2023-11-08 04:11:59.146561: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094e9571900 of size 12582912 next 19
# 2023-11-08 04:11:59.146591: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ea171900 of size 12582912 next 20
# 2023-11-08 04:11:59.146624: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ead71900 of size 12582912 next 21
# 2023-11-08 04:11:59.146647: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094eb971900 of size 12582912 next 16
# 2023-11-08 04:11:59.146669: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ec571900 of size 12582912 next 22
# 2023-11-08 04:11:59.146692: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ed171900 of size 12582912 next 24
# 2023-11-08 04:11:59.146711: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094edd71900 of size 12582912 next 18
# 2023-11-08 04:11:59.146733: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ee971900 of size 12582912 next 25
# 2023-11-08 04:11:59.146771: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ef571900 of size 12582912 next 27
# 2023-11-08 04:11:59.146803: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f0171900 of size 12582912 next 23
# 2023-11-08 04:11:59.146833: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f0d71900 of size 12582912 next 29
# 2023-11-08 04:11:59.146865: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f1971900 of size 12582912 next 30
# 2023-11-08 04:11:59.146898: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f2571900 of size 12582912 next 31
# 2023-11-08 04:11:59.146924: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f3171900 of size 12582912 next 26
# 2023-11-08 04:11:59.146946: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f3d71900 of size 12582912 next 32
# 2023-11-08 04:11:59.146964: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f4971900 of size 12582912 next 33
# 2023-11-08 04:11:59.146995: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f5571900 of size 12582912 next 35
# 2023-11-08 04:11:59.147030: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f6171900 of size 12582912 next 36
# 2023-11-08 04:11:59.147060: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f6d71900 of size 12582912 next 34
# 2023-11-08 04:11:59.147093: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f7971900 of size 12582912 next 38
# 2023-11-08 04:11:59.147124: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f8571900 of size 12582912 next 28
# 2023-11-08 04:11:59.147153: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f9171900 of size 12582912 next 39
# 2023-11-08 04:11:59.147184: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094f9d71900 of size 12582912 next 41
# 2023-11-08 04:11:59.147202: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fa971900 of size 12582912 next 37
# 2023-11-08 04:11:59.147229: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fb571900 of size 12582912 next 42
# 2023-11-08 04:11:59.147266: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fc171900 of size 12582912 next 44
# 2023-11-08 04:11:59.147297: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fcd71900 of size 12582912 next 40
# 2023-11-08 04:11:59.147327: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fd971900 of size 12582912 next 46
# 2023-11-08 04:11:59.147360: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094fe571900 of size 12582912 next 47
# 2023-11-08 04:11:59.147385: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ff171900 of size 12582912 next 45
# 2023-11-08 04:11:59.147407: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7094ffd71900 of size 12582912 next 49
# 2023-11-08 04:11:59.147429: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709500971900 of size 12582912 next 43
# 2023-11-08 04:11:59.147449: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709501571900 of size 12582912 next 51
# 2023-11-08 04:11:59.147485: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709502171900 of size 12582912 next 48
# 2023-11-08 04:11:59.147518: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709502d71900 of size 12582912 next 52
# 2023-11-08 04:11:59.147547: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709503971900 of size 12582912 next 53
# 2023-11-08 04:11:59.147578: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709504571900 of size 12582912 next 54
# 2023-11-08 04:11:59.147609: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709505171900 of size 12582912 next 56
# 2023-11-08 04:11:59.147632: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709505d71900 of size 12582912 next 57
# 2023-11-08 04:11:59.147655: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709506971900 of size 12582912 next 55
# 2023-11-08 04:11:59.147673: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709507571900 of size 12582912 next 59
# 2023-11-08 04:11:59.147699: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709508171900 of size 12582912 next 60
# 2023-11-08 04:11:59.147736: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709508d71900 of size 12582912 next 58
# 2023-11-08 04:11:59.147767: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709509971900 of size 12582912 next 62
# 2023-11-08 04:11:59.147798: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950a571900 of size 12582912 next 63
# 2023-11-08 04:11:59.147829: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950b171900 of size 12582912 next 64
# 2023-11-08 04:11:59.147851: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950bd71900 of size 12582912 next 50
# 2023-11-08 04:11:59.147872: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950c971900 of size 12582912 next 66
# 2023-11-08 04:11:59.147894: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950d571900 of size 12582912 next 67
# 2023-11-08 04:11:59.147912: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950e171900 of size 12582912 next 65
# 2023-11-08 04:11:59.147948: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950ed71900 of size 12582912 next 68
# 2023-11-08 04:11:59.147981: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70950f971900 of size 12582912 next 70
# 2023-11-08 04:11:59.148010: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709510571900 of size 12582912 next 61
# 2023-11-08 04:11:59.148043: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709511171900 of size 12582912 next 72
# 2023-11-08 04:11:59.148066: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709511d71900 of size 12582912 next 73
# 2023-11-08 04:11:59.148088: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709512971900 of size 12582912 next 74
# 2023-11-08 04:11:59.148111: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709513571900 of size 12582912 next 75
# 2023-11-08 04:11:59.148129: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709514171900 of size 12582912 next 76
# 2023-11-08 04:11:59.148153: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709514d71900 of size 12582912 next 69
# 2023-11-08 04:11:59.148190: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709515971900 of size 12582912 next 77
# 2023-11-08 04:11:59.148221: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709516571900 of size 12582912 next 79
# 2023-11-08 04:11:59.148253: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709517171900 of size 12582912 next 71
# 2023-11-08 04:11:59.148281: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709517d71900 of size 12582912 next 80
# 2023-11-08 04:11:59.148303: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709518971900 of size 12582912 next 81
# 2023-11-08 04:11:59.148325: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709519571900 of size 12582912 next 82
# 2023-11-08 04:11:59.148347: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951a171900 of size 12582912 next 83
# 2023-11-08 04:11:59.148364: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951ad71900 of size 12582912 next 85
# 2023-11-08 04:11:59.148394: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951b971900 of size 12582912 next 86
# 2023-11-08 04:11:59.148431: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951c571900 of size 12582912 next 87
# 2023-11-08 04:11:59.148462: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951d171900 of size 12582912 next 88
# 2023-11-08 04:11:59.148495: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951dd71900 of size 12582912 next 84
# 2023-11-08 04:11:59.148527: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951e971900 of size 12582912 next 90
# 2023-11-08 04:11:59.148555: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70951f571900 of size 12582912 next 91
# 2023-11-08 04:11:59.148579: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709520171900 of size 12582912 next 92
# 2023-11-08 04:11:59.148597: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709520d71900 of size 12582912 next 78
# 2023-11-08 04:11:59.148621: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709521971900 of size 12582912 next 93
# 2023-11-08 04:11:59.148658: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709522571900 of size 12582912 next 94
# 2023-11-08 04:11:59.148690: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709523171900 of size 12582912 next 95
# 2023-11-08 04:11:59.148721: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709523d71900 of size 12582912 next 97
# 2023-11-08 04:11:59.148752: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709524971900 of size 12582912 next 89
# 2023-11-08 04:11:59.148775: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709525571900 of size 12582912 next 98
# 2023-11-08 04:11:59.148796: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709526171900 of size 12582912 next 100
# 2023-11-08 04:11:59.148819: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709526d71900 of size 12582912 next 96
# 2023-11-08 04:11:59.148837: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709527971900 of size 12582912 next 101
# 2023-11-08 04:11:59.148871: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709528571900 of size 12582912 next 102
# 2023-11-08 04:11:59.148905: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709529171900 of size 12582912 next 104
# 2023-11-08 04:11:59.148934: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709529d71900 of size 12582912 next 99
# 2023-11-08 04:11:59.148968: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952a971900 of size 12582912 next 106
# 2023-11-08 04:11:59.148993: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952b571900 of size 12582912 next 107
# 2023-11-08 04:11:59.149015: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952c171900 of size 12582912 next 108
# 2023-11-08 04:11:59.149039: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952cd71900 of size 12582912 next 103
# 2023-11-08 04:11:59.149056: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952d971900 of size 12582912 next 109
# 2023-11-08 04:11:59.149082: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952e571900 of size 12582912 next 111
# 2023-11-08 04:11:59.149119: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952f171900 of size 12582912 next 112
# 2023-11-08 04:11:59.149150: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70952fd71900 of size 12582912 next 110
# 2023-11-08 04:11:59.149181: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709530971900 of size 12582912 next 114
# 2023-11-08 04:11:59.149213: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709531571900 of size 12582912 next 105
# 2023-11-08 04:11:59.149236: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709532171900 of size 12582912 next 115
# 2023-11-08 04:11:59.149258: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709532d71900 of size 12582912 next 116
# 2023-11-08 04:11:59.149279: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709533971900 of size 12582912 next 117
# 2023-11-08 04:11:59.149299: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709534571900 of size 12582912 next 118
# 2023-11-08 04:11:59.149334: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709535171900 of size 12582912 next 120
# 2023-11-08 04:11:59.149366: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709535d71900 of size 12582912 next 121
# 2023-11-08 04:11:59.149395: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709536971900 of size 12582912 next 122
# 2023-11-08 04:11:59.149428: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709537571900 of size 12582912 next 113
# 2023-11-08 04:11:59.149456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709538171900 of size 12582912 next 123
# 2023-11-08 04:11:59.149478: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709538d71900 of size 12582912 next 124
# 2023-11-08 04:11:59.149501: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709539971900 of size 12582912 next 125
# 2023-11-08 04:11:59.149518: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953a571900 of size 12582912 next 127
# 2023-11-08 04:11:59.149546: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953b171900 of size 12582912 next 119
# 2023-11-08 04:11:59.149582: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953bd71900 of size 12582912 next 128
# 2023-11-08 04:11:59.149613: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953c971900 of size 12582912 next 129
# 2023-11-08 04:11:59.149644: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953d571900 of size 12582912 next 130
# 2023-11-08 04:11:59.149681: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953e171900 of size 12582912 next 131
# 2023-11-08 04:11:59.149704: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953ed71900 of size 12582912 next 132
# 2023-11-08 04:11:59.149726: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70953f971900 of size 12582912 next 133
# 2023-11-08 04:11:59.149751: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709540571900 of size 12582912 next 134
# 2023-11-08 04:11:59.149768: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709541171900 of size 12582912 next 136
# 2023-11-08 04:11:59.149800: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709541d71900 of size 12582912 next 126
# 2023-11-08 04:11:59.149834: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709542971900 of size 12582912 next 138
# 2023-11-08 04:11:59.149864: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709543571900 of size 12582912 next 139
# 2023-11-08 04:11:59.149897: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709544171900 of size 12582912 next 140
# 2023-11-08 04:11:59.149925: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709544d71900 of size 12582912 next 135
# 2023-11-08 04:11:59.149947: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709545971900 of size 12582912 next 142
# 2023-11-08 04:11:59.149970: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709546571900 of size 12582912 next 137
# 2023-11-08 04:11:59.149989: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709547171900 of size 12582912 next 143
# 2023-11-08 04:11:59.150010: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709547d71900 of size 12582912 next 145
# 2023-11-08 04:11:59.150047: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709548971900 of size 12582912 next 146
# 2023-11-08 04:11:59.150079: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709549571900 of size 12582912 next 144
# 2023-11-08 04:11:59.150109: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954a171900 of size 12582912 next 147
# 2023-11-08 04:11:59.150141: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954ad71900 of size 12582912 next 149
# 2023-11-08 04:11:59.150163: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954b971900 of size 12582912 next 141
# 2023-11-08 04:11:59.150184: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954c571900 of size 12582912 next 150
# 2023-11-08 04:11:59.150208: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954d171900 of size 12582912 next 152
# 2023-11-08 04:11:59.150224: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954dd71900 of size 12582912 next 148
# 2023-11-08 04:11:59.150254: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954e971900 of size 12582912 next 153
# 2023-11-08 04:11:59.150290: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70954f571900 of size 12582912 next 154
# 2023-11-08 04:11:59.150321: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709550171900 of size 12582912 next 156
# 2023-11-08 04:11:59.150353: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709550d71900 of size 12582912 next 157
# 2023-11-08 04:11:59.150385: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709551971900 of size 12582912 next 155
# 2023-11-08 04:11:59.150416: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709552571900 of size 12582912 next 158
# 2023-11-08 04:11:59.150441: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709553171900 of size 12582912 next 160
# 2023-11-08 04:11:59.150459: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709553d71900 of size 12582912 next 161
# 2023-11-08 04:11:59.150481: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709554971900 of size 12582912 next 162
# 2023-11-08 04:11:59.150519: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709555571900 of size 12582912 next 151
# 2023-11-08 04:11:59.150550: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709556171900 of size 12582912 next 164
# 2023-11-08 04:11:59.150581: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709556d71900 of size 12582912 next 165
# 2023-11-08 04:11:59.150613: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709557971900 of size 12582912 next 166
# 2023-11-08 04:11:59.150644: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709558571900 of size 12582912 next 167
# 2023-11-08 04:11:59.150668: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709559171900 of size 12582912 next 168
# 2023-11-08 04:11:59.150689: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709559d71900 of size 12582912 next 159
# 2023-11-08 04:11:59.150709: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955a971900 of size 12582912 next 170
# 2023-11-08 04:11:59.150745: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955b571900 of size 12582912 next 171
# 2023-11-08 04:11:59.150777: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955c171900 of size 12582912 next 169
# 2023-11-08 04:11:59.150808: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955cd71900 of size 12582912 next 173
# 2023-11-08 04:11:59.150840: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955d971900 of size 12582912 next 163
# 2023-11-08 04:11:59.150871: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955e571900 of size 12582912 next 174
# 2023-11-08 04:11:59.150894: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955f171900 of size 12582912 next 176
# 2023-11-08 04:11:59.150917: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70955fd71900 of size 12582912 next 177
# 2023-11-08 04:11:59.150933: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709560971900 of size 12582912 next 175
# 2023-11-08 04:11:59.150966: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709561571900 of size 12582912 next 178
# 2023-11-08 04:11:59.151001: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709562171900 of size 12582912 next 179
# 2023-11-08 04:11:59.151032: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709562d71900 of size 12582912 next 181
# 2023-11-08 04:11:59.151064: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709563971900 of size 12582912 next 182
# 2023-11-08 04:11:59.151096: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709564571900 of size 12582912 next 183
# 2023-11-08 04:11:59.151125: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709565171900 of size 12582912 next 184
# 2023-11-08 04:11:59.151148: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709565d71900 of size 12582912 next 180
# 2023-11-08 04:11:59.151166: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709566971900 of size 12582912 next 185
# 2023-11-08 04:11:59.151189: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709567571900 of size 12582912 next 186
# 2023-11-08 04:11:59.151225: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709568171900 of size 12582912 next 188
# 2023-11-08 04:11:59.151255: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709568d71900 of size 12582912 next 189
# 2023-11-08 04:11:59.151286: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709569971900 of size 12582912 next 187
# 2023-11-08 04:11:59.151316: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956a571900 of size 12582912 next 190
# 2023-11-08 04:11:59.151338: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956b171900 of size 12582912 next 191
# 2023-11-08 04:11:59.151360: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956bd71900 of size 12582912 next 192
# 2023-11-08 04:11:59.151382: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956c971900 of size 12582912 next 193
# 2023-11-08 04:11:59.151399: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956d571900 of size 12582912 next 194
# 2023-11-08 04:11:59.151433: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956e171900 of size 12582912 next 195
# 2023-11-08 04:11:59.151467: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956ed71900 of size 12582912 next 196
# 2023-11-08 04:11:59.151496: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70956f971900 of size 12582912 next 198
# 2023-11-08 04:11:59.151528: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709570571900 of size 12582912 next 199
# 2023-11-08 04:11:59.151551: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709571171900 of size 12582912 next 197
# 2023-11-08 04:11:59.151573: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709571d71900 of size 12582912 next 201
# 2023-11-08 04:11:59.151596: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709572971900 of size 12582912 next 202
# 2023-11-08 04:11:59.151614: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709573571900 of size 12582912 next 203
# 2023-11-08 04:11:59.151636: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709574171900 of size 12582912 next 172
# 2023-11-08 04:11:59.151674: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709574d71900 of size 12582912 next 204
# 2023-11-08 04:11:59.151705: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709575971900 of size 12582912 next 206
# 2023-11-08 04:11:59.151737: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709576571900 of size 12582912 next 200
# 2023-11-08 04:11:59.151769: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709577171900 of size 12582912 next 208
# 2023-11-08 04:11:59.151798: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709577d71900 of size 12582912 next 209
# 2023-11-08 04:11:59.151821: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709578971900 of size 12582912 next 207
# 2023-11-08 04:11:59.151843: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709579571900 of size 12582912 next 210
# 2023-11-08 04:11:59.151860: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957a171900 of size 12582912 next 212
# 2023-11-08 04:11:59.151891: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957ad71900 of size 12582912 next 213
# 2023-11-08 04:11:59.151927: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957b971900 of size 12582912 next 214
# 2023-11-08 04:11:59.151956: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957c571900 of size 12582912 next 205
# 2023-11-08 04:11:59.151986: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957d171900 of size 12582912 next 216
# 2023-11-08 04:11:59.152014: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957dd71900 of size 12582912 next 217
# 2023-11-08 04:11:59.152043: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957e971900 of size 12582912 next 215
# 2023-11-08 04:11:59.152077: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70957f571900 of size 12582912 next 218
# 2023-11-08 04:11:59.152108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709580171900 of size 12582912 next 219
# 2023-11-08 04:11:59.152148: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709580d71900 of size 12582912 next 220
# 2023-11-08 04:11:59.152181: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709581971900 of size 12582912 next 221
# 2023-11-08 04:11:59.152214: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709582571900 of size 12582912 next 222
# 2023-11-08 04:11:59.152247: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709583171900 of size 12582912 next 223
# 2023-11-08 04:11:59.152275: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709583d71900 of size 12582912 next 224
# 2023-11-08 04:11:59.152299: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709584971900 of size 12582912 next 226
# 2023-11-08 04:11:59.152318: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709585571900 of size 12582912 next 211
# 2023-11-08 04:11:59.152340: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709586171900 of size 12582912 next 228
# 2023-11-08 04:11:59.152375: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709586d71900 of size 12582912 next 225
# 2023-11-08 04:11:59.152407: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709587971900 of size 12582912 next 229
# 2023-11-08 04:11:59.152438: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709588571900 of size 12582912 next 231
# 2023-11-08 04:11:59.152467: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709589171900 of size 12582912 next 227
# 2023-11-08 04:11:59.152490: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709589d71900 of size 12582912 next 232
# 2023-11-08 04:11:59.152511: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958a971900 of size 12582912 next 234
# 2023-11-08 04:11:59.152534: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958b571900 of size 12582912 next 230
# 2023-11-08 04:11:59.152550: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958c171900 of size 12582912 next 235
# 2023-11-08 04:11:59.152583: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958cd71900 of size 12582912 next 237
# 2023-11-08 04:11:59.152618: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958d971900 of size 12582912 next 238
# 2023-11-08 04:11:59.152648: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958e571900 of size 12582912 next 236
# 2023-11-08 04:11:59.152681: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958f171900 of size 12582912 next 239
# 2023-11-08 04:11:59.152713: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70958fd71900 of size 12582912 next 241
# 2023-11-08 04:11:59.152738: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709590971900 of size 12582912 next 233
# 2023-11-08 04:11:59.152762: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709591571900 of size 12582912 next 242
# 2023-11-08 04:11:59.152780: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709592171900 of size 12582912 next 243
# 2023-11-08 04:11:59.152805: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709592d71900 of size 12582912 next 245
# 2023-11-08 04:11:59.152840: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709593971900 of size 12582912 next 240
# 2023-11-08 04:11:59.152870: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709594571900 of size 12582912 next 246
# 2023-11-08 04:11:59.152903: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709595171900 of size 12582912 next 247
# 2023-11-08 04:11:59.152928: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709595d71900 of size 12582912 next 249
# 2023-11-08 04:11:59.152950: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709596971900 of size 12582912 next 250
# 2023-11-08 04:11:59.152971: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709597571900 of size 12582912 next 248
# 2023-11-08 04:11:59.152994: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709598171900 of size 12582912 next 252
# 2023-11-08 04:11:59.153012: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709598d71900 of size 12582912 next 253
# 2023-11-08 04:11:59.153049: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709599971900 of size 12582912 next 251
# 2023-11-08 04:11:59.153081: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959a571900 of size 12582912 next 254
# 2023-11-08 04:11:59.153111: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959b171900 of size 12582912 next 256
# 2023-11-08 04:11:59.153142: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959bd71900 of size 12582912 next 244
# 2023-11-08 04:11:59.153165: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959c971900 of size 12582912 next 257
# 2023-11-08 04:11:59.153187: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959d571900 of size 12582912 next 258
# 2023-11-08 04:11:59.153210: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959e171900 of size 12582912 next 259
# 2023-11-08 04:11:59.153227: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959ed71900 of size 12582912 next 260
# 2023-11-08 04:11:59.153255: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 70959f971900 of size 12582912 next 262
# 2023-11-08 04:11:59.153291: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7095a0571900 of size 12582912 next 255
# 2023-11-08 04:11:59.153321: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7095a1171900 of size 12582912 next 264
# 2023-11-08 04:11:59.153353: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7095a1d71900 of size 12582912 next 265
# 2023-11-08 04:11:59.153386: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7095a2971900 of size 12582912 next 266
# 2023-11-08 04:11:59.153415: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7095a3571900 of size 12582912 next 261
# ...
# 2023-11-08 04:11:59.187668: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c02971900 of size 12582912 next 2442
# 2023-11-08 04:11:59.187686: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c03571900 of size 12582912 next 2423
# 2023-11-08 04:11:59.187700: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c04171900 of size 12582912 next 2444
# 2023-11-08 04:11:59.187714: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c04d71900 of size 12582912 next 2445
# 2023-11-08 04:11:59.187728: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c05971900 of size 12582912 next 2443
# 2023-11-08 04:11:59.187742: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c06571900 of size 12582912 next 2446
# 2023-11-08 04:11:59.187755: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c07171900 of size 12582912 next 2448
# 2023-11-08 04:11:59.187769: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c07d71900 of size 12582912 next 2449
# 2023-11-08 04:11:59.187786: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c08971900 of size 12582912 next 2447
# 2023-11-08 04:11:59.187808: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c09571900 of size 12582912 next 2451
# 2023-11-08 04:11:59.187823: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0a171900 of size 12582912 next 2441
# 2023-11-08 04:11:59.187837: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0ad71900 of size 12582912 next 2452
# 2023-11-08 04:11:59.187851: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0b971900 of size 12582912 next 2454
# 2023-11-08 04:11:59.187865: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0c571900 of size 12582912 next 2455
# 2023-11-08 04:11:59.187878: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0d171900 of size 12582912 next 2456
# 2023-11-08 04:11:59.187892: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0dd71900 of size 12582912 next 2457
# 2023-11-08 04:11:59.187906: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0e971900 of size 12582912 next 2458
# 2023-11-08 04:11:59.187926: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c0f571900 of size 12582912 next 2459
# 2023-11-08 04:11:59.187944: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c10171900 of size 12582912 next 2460
# 2023-11-08 04:11:59.187957: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c10d71900 of size 12582912 next 2461
# 2023-11-08 04:11:59.187972: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c11971900 of size 12582912 next 2462
# 2023-11-08 04:11:59.187985: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c12571900 of size 12582912 next 2463
# 2023-11-08 04:11:59.187998: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c13171900 of size 12582912 next 2464
# 2023-11-08 04:11:59.188013: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c13d71900 of size 12582912 next 2450
# 2023-11-08 04:11:59.188025: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c14971900 of size 12582912 next 2465
# 2023-11-08 04:11:59.188044: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c15571900 of size 12582912 next 2467
# 2023-11-08 04:11:59.188065: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c16171900 of size 12582912 next 2453
# 2023-11-08 04:11:59.188080: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c16d71900 of size 12582912 next 2469
# 2023-11-08 04:11:59.188094: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c17971900 of size 12582912 next 2466
# 2023-11-08 04:11:59.188108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c18571900 of size 12582912 next 2470
# 2023-11-08 04:11:59.188121: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c19171900 of size 12582912 next 2472
# 2023-11-08 04:11:59.188134: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c19d71900 of size 12582912 next 2473
# 2023-11-08 04:11:59.188149: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1a971900 of size 12582912 next 2474
# 2023-11-08 04:11:59.188164: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1b571900 of size 12582912 next 2468
# 2023-11-08 04:11:59.188185: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1c171900 of size 12582912 next 2475
# 2023-11-08 04:11:59.188199: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1cd71900 of size 12582912 next 2476
# 2023-11-08 04:11:59.188213: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1d971900 of size 12582912 next 2478
# 2023-11-08 04:11:59.188227: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1e571900 of size 12582912 next 2471
# 2023-11-08 04:11:59.188241: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1f171900 of size 12582912 next 2480
# 2023-11-08 04:11:59.188254: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c1fd71900 of size 12582912 next 2481
# 2023-11-08 04:11:59.188268: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c20971900 of size 12582912 next 2482
# 2023-11-08 04:11:59.188281: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c21571900 of size 12582912 next 2483
# 2023-11-08 04:11:59.188301: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c22171900 of size 12582912 next 2484
# 2023-11-08 04:11:59.188319: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c22d71900 of size 12582912 next 2485
# 2023-11-08 04:11:59.188333: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c23971900 of size 12582912 next 2479
# 2023-11-08 04:11:59.188347: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c24571900 of size 12582912 next 2486
# 2023-11-08 04:11:59.188362: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c25171900 of size 12582912 next 2488
# 2023-11-08 04:11:59.188375: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c25d71900 of size 12582912 next 2477
# 2023-11-08 04:11:59.188388: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c26971900 of size 12582912 next 2490
# 2023-11-08 04:11:59.188402: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c27571900 of size 12582912 next 2491
# 2023-11-08 04:11:59.188417: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c28171900 of size 12582912 next 2492
# 2023-11-08 04:11:59.188437: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c28d71900 of size 12582912 next 2487
# 2023-11-08 04:11:59.188453: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c29971900 of size 12582912 next 2494
# 2023-11-08 04:11:59.188466: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2a571900 of size 12582912 next 2489
# 2023-11-08 04:11:59.188481: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2b171900 of size 12582912 next 2495
# 2023-11-08 04:11:59.188495: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2bd71900 of size 12582912 next 2496
# 2023-11-08 04:11:59.188508: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2c971900 of size 12582912 next 2498
# 2023-11-08 04:11:59.188522: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2d571900 of size 12582912 next 2499
# 2023-11-08 04:11:59.188535: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2e171900 of size 12582912 next 2500
# 2023-11-08 04:11:59.188555: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2ed71900 of size 12582912 next 2493
# 2023-11-08 04:11:59.188571: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c2f971900 of size 12582912 next 2501
# 2023-11-08 04:11:59.188585: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c30571900 of size 12582912 next 2503
# 2023-11-08 04:11:59.188599: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c31171900 of size 12582912 next 2504
# 2023-11-08 04:11:59.188613: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c31d71900 of size 12582912 next 2505
# 2023-11-08 04:11:59.188626: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c32971900 of size 12582912 next 2497
# 2023-11-08 04:11:59.188640: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c33571900 of size 12582912 next 2507
# 2023-11-08 04:11:59.188653: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c34171900 of size 12582912 next 2508
# 2023-11-08 04:11:59.188671: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c34d71900 of size 12582912 next 2506
# 2023-11-08 04:11:59.188689: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c35971900 of size 12582912 next 2510
# 2023-11-08 04:11:59.188704: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c36571900 of size 12582912 next 2511
# 2023-11-08 04:11:59.188717: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c37171900 of size 12582912 next 2509
# 2023-11-08 04:11:59.188732: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c37d71900 of size 12582912 next 2512
# 2023-11-08 04:11:59.188745: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c38971900 of size 12582912 next 2514
# 2023-11-08 04:11:59.188759: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c39571900 of size 12582912 next 2515
# 2023-11-08 04:11:59.188773: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c3a171900 of size 12582912 next 2516
# 2023-11-08 04:11:59.188790: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c3ad71900 of size 12582912 next 2502
# 2023-11-08 04:11:59.188809: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 709c3b971900 of size 19481344 next 18446744073709551615
# 2023-11-08 04:11:59.188822: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2023-11-08 04:11:59.188842: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 256 totalling 768B
# 2023-11-08 04:11:59.188859: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-11-08 04:11:59.188875: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3575296 totalling 3.41MiB
# 2023-11-08 04:11:59.188892: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2508 Chunks of size 12582912 totalling 29.39GiB
# 2023-11-08 04:11:59.188911: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 18288896 totalling 17.44MiB
# 2023-11-08 04:11:59.188935: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 19481344 totalling 18.58MiB
# 2023-11-08 04:11:59.188951: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 29.43GiB
# 2023-11-08 04:11:59.188967: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 31620881408 memory_limit_: 31620881536 available bytes: 128 curr_region_allocation_bytes_: 63241763328
# 2023-11-08 04:11:59.188988: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                     31620881536
# InUse:                     31599290880
# MaxInUse:                  31620881408
# NumAllocs:                       28849
# MaxAllocSize:                 28287488
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-08 04:11:59.189045: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ****************************************************************************************************
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_36325/3068222973.py in <module>
#       1 # Apply the preprocessing operations to the training data
# ----> 2 train_ori = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, train_ori_imgs))))
#       3 train_nbi = tf.data.Dataset.from_tensor_slices(np.array(list(map(preprocess_train_image, train_nbi_imgs))))
#       4
#       5 if batch_size != 1:
#
# /tmp/ipykernel_36325/2659218950.py in preprocess_train_image(img)
#      24     img = tf.image.random_flip_left_right(img)
#      25     # Resize to the original size first
# ---> 26     img = tf.image.resize(img, [*orig_img_size])
#      27     # Random crop to 256X256
#      28     img = tf.image.random_crop(img, size=[*input_img_size])
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/ops/image_ops_impl.py in resize_images_v2(images, size, method, preserve_aspect_ratio, antialias, name)
#    1645       preserve_aspect_ratio=preserve_aspect_ratio,
#    1646       name=name,
# -> 1647       skip_resize_if_same=False)
#    1648
#    1649
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/ops/image_ops_impl.py in _resize_images_common(images, resizer_fn, size, preserve_aspect_ratio, name, skip_resize_if_same)
#    1379
#    1380     if not is_batch:
# -> 1381       images = array_ops.squeeze(images, axis=[0])
#    1382     return images
#    1383
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     536                 'in a future version' if date is None else ('after %s' % date),
#     537                 instructions)
# --> 538       return func(*args, **kwargs)
#     539
#     540     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in squeeze(input, axis, name, squeeze_dims)
#    4377   if np.isscalar(axis):
#    4378     axis = [axis]
# -> 4379   return gen_array_ops.squeeze(input, axis, name)
#    4380
#    4381
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in squeeze(input, axis, name)
#   10154       return _result
#   10155     except _core._NotOkStatusException as e:
# > 10156       _ops.raise_from_not_ok_status(e, name)
#   10157     except _core._FallbackException:
#   10158       pass
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# ~/anaconda3/envs/nipa/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Squeeze: Dst tensor is not initialized. [Op:Squeeze]

# %% [markdown]
# ### Visualize some samples

# %%
_, ax = plt.subplots(4,2, figsize=(5,10))

for i, samples in enumerate(zip(train_ori.take(4), train_nbi.take(4))):
    ori = ((samples[0][0] * 127.5 + 127.5).numpy()).astype(np.uint8)
    nbi = ((samples[1][0] * 127.5 + 127.5).numpy()).astype(np.uint8)
    
    ax[i, 0].imshow(ori)
    ax[i, 1].imshow(nbi)

plt.show()

# %% [markdown]
# ### Building blocks used in the CycleGAN generators and discriminators

# %%
class ReflectionPadding2D(layers.Layer):
    """Implements Reflection Padding as a layer.

    Args:
        padding(tuple): Amount of padding for the
        spatial dimensions.

    Returns:
        A padded tensor with the same type as the input tensor.
    """

    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        super().__init__(**kwargs)

    def call(self, input_tensor, mask=None):
        padding_width, padding_height = self.padding
        padding_tensor = [
            [0, 0],
            [padding_height, padding_height],
            [padding_width, padding_width],
            [0, 0],
        ]
        return tf.pad(input_tensor, padding_tensor, mode="REFLECT")


def residual_block(
    x,
    activation,
    kernel_initializer=kernel_init,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="valid",
    gamma_initializer=gamma_init,
    use_bias=False,
):
    dim = x.shape[-1]
    input_tensor = x

    x = ReflectionPadding2D()(input_tensor)
    x = layers.Conv2D(
        dim,
        kernel_size,
        strides=strides,
        kernel_initializer=kernel_initializer,
        padding=padding,
        use_bias=use_bias,
    )(x)
    x = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(x)
    x = activation(x)

    x = ReflectionPadding2D()(x)
    x = layers.Conv2D(
        dim,
        kernel_size,
        strides=strides,
        kernel_initializer=kernel_initializer,
        padding=padding,
        use_bias=use_bias,
    )(x)
    x = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(x)
    x = layers.add([input_tensor, x])
    return x


def downsample(
    x,
    filters,
    activation,
    kernel_initializer=kernel_init,
    kernel_size=(3, 3),
    strides=(2, 2),
    padding="same",
    gamma_initializer=gamma_init,
    use_bias=False,
):
    x = layers.Conv2D(
        filters,
        kernel_size,
        strides=strides,
        kernel_initializer=kernel_initializer,
        padding=padding,
        use_bias=use_bias,
    )(x)
    x = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(x)
    if activation:
        x = activation(x)
    return x


def upsample(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(2, 2),
    padding="same",
    kernel_initializer=kernel_init,
    gamma_initializer=gamma_init,
    use_bias=False,
):
    x = layers.Conv2DTranspose(
        filters,
        kernel_size,
        strides=strides,
        padding=padding,
        kernel_initializer=kernel_initializer,
        use_bias=use_bias,
    )(x)
    x = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(x)
    if activation:
        x = activation(x)
    return x

# %% [markdown]
# ### Build the generators

# %% [raw]
# c7s1-64 ==> Conv block with `relu` activation, filter size of 7
# d128 ====|
#          |-> 2 downsampling blocks
# d256 ====|
# R256 ====|
# R256     |
# R256     |
# R256     |
# R256     |-> 9 residual blocks
# R256     |
# R256     |
# R256     |
# R256 ====|
# u128 ====|
#          |-> 2 upsampling blocks
# u64  ====|
# c7s1-3 => Last conv block with `tanh` activation, filter size of 7

# %%
def get_resnet_generator(
    filters=64,
    num_downsampling_blocks=2,
    num_residual_blocks=9,
    num_upsample_blocks=2,
    gamma_initializer=gamma_init,
    name=None,
):
    img_input = layers.Input(shape=input_img_size, name=name + "_img_input")
    
    x = ReflectionPadding2D(padding=(3, 3))(img_input)
    x = layers.Conv2D(filters, (7, 7), kernel_initializer=kernel_init, use_bias=False)(
        x
    )
    x = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(x)
    x = layers.Activation("relu")(x)

    # Downsampling
    for _ in range(num_downsampling_blocks):
        filters *= 2
        x = downsample(x, filters=filters, activation=layers.Activation("relu"))

    # Residual blocks
    for _ in range(num_residual_blocks):
        x = residual_block(x, activation=layers.Activation("relu"))

    # Upsampling
    for _ in range(num_upsample_blocks):
        filters //= 2
        x = upsample(x, filters, activation=layers.Activation("relu"))

    # Final block
    x = ReflectionPadding2D(padding=(3, 3))(x)
    x = layers.Conv2D(3, (7, 7), padding="valid")(x)
    x = layers.Activation("tanh")(x)

    model = keras.models.Model(img_input, x, name=name)
    return model

# %% [markdown]
# ### Build the discriminators

# %%
def get_discriminator(
    filters=64, kernel_initializer=kernel_init, num_downsampling=3, name=None
):
    img_input = layers.Input(shape=input_img_size, name=name + "_img_input")
    x = layers.Conv2D(
        filters,
        (4, 4),
        strides=(2, 2),
        padding="same",
        kernel_initializer=kernel_initializer,
    )(img_input)
    x = layers.LeakyReLU(0.2)(x)

    num_filters = filters
    for num_downsample_block in range(3):
        num_filters *= 2
        if num_downsample_block < 2:
            x = downsample(
                x,
                filters=num_filters,
                activation=layers.LeakyReLU(0.2),
                kernel_size=(4, 4),
                strides=(2, 2),
            )
        else:
            x = downsample(
                x,
                filters=num_filters,
                activation=layers.LeakyReLU(0.2),
                kernel_size=(4, 4),
                strides=(1, 1),
            )

    x = layers.Conv2D(
        1, (4, 4), strides=(1, 1), padding="same", kernel_initializer=kernel_initializer
    )(x)

    model = keras.models.Model(inputs=img_input, outputs=x, name=name)
    return model


# Get the generators
gen_G = get_resnet_generator(name="generator_G")
gen_F = get_resnet_generator(name="generator_F")

# Get the discriminators
disc_X = get_discriminator(name="discriminator_X")
disc_Y = get_discriminator(name="discriminator_Y")

# %% [markdown]
# ### Build the CycleGAN model

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        generator_G,
        generator_F,
        discriminator_X,
        discriminator_Y,
        lambda_cycle=10.0,
        lambda_identity=0.5,
    ):
        super().__init__()
        self.gen_G = generator_G
        self.gen_F = generator_F
        self.disc_X = discriminator_X
        self.disc_Y = discriminator_Y
        self.lambda_cycle = lambda_cycle
        self.lambda_identity = lambda_identity

    def compile(
        self,
        gen_G_optimizer,
        gen_F_optimizer,
        disc_X_optimizer,
        disc_Y_optimizer,
        gen_loss_fn,
        disc_loss_fn,
    ):
        super().compile()
        self.gen_G_optimizer = gen_G_optimizer
        self.gen_F_optimizer = gen_F_optimizer
        self.disc_X_optimizer = disc_X_optimizer
        self.disc_Y_optimizer = disc_Y_optimizer
        self.generator_loss_fn = gen_loss_fn
        self.discriminator_loss_fn = disc_loss_fn
        self.cycle_loss_fn = keras.losses.MeanAbsoluteError()
        self.identity_loss_fn = keras.losses.MeanAbsoluteError()

    def train_step(self, batch_data):
        # x is Horse and y is zebra
        real_x, real_y = batch_data

        # For CycleGAN, we need to calculate different
        # kinds of losses for the generators and discriminators.
        # We will perform the following steps here:
        #
        # 1. Pass real images through the generators and get the generated images
        # 2. Pass the generated images back to the generators to check if we
        #    can predict the original image from the generated image.
        # 3. Do an identity mapping of the real images using the generators.
        # 4. Pass the generated images in 1) to the corresponding discriminators.
        # 5. Calculate the generators total loss (adversarial + cycle + identity)
        # 6. Calculate the discriminators loss
        # 7. Update the weights of the generators
        # 8. Update the weights of the discriminators
        # 9. Return the losses in a dictionary

        with tf.GradientTape(persistent=True) as tape:
            # Horse to fake zebra
            fake_y = self.gen_G(real_x, training=True)
            # Zebra to fake horse -> y2x
            fake_x = self.gen_F(real_y, training=True)

            # Cycle (Horse to fake zebra to fake horse): x -> y -> x
            cycled_x = self.gen_F(fake_y, training=True)
            # Cycle (Zebra to fake horse to fake zebra) y -> x -> y
            cycled_y = self.gen_G(fake_x, training=True)

            # Identity mapping
            same_x = self.gen_F(real_x, training=True)
            same_y = self.gen_G(real_y, training=True)

            # Discriminator output
            disc_real_x = self.disc_X(real_x, training=True)
            disc_fake_x = self.disc_X(fake_x, training=True)

            disc_real_y = self.disc_Y(real_y, training=True)
            disc_fake_y = self.disc_Y(fake_y, training=True)

            # Generator adversarial loss
            gen_G_loss = self.generator_loss_fn(disc_fake_y)
            gen_F_loss = self.generator_loss_fn(disc_fake_x)

            # Generator cycle loss
            cycle_loss_G = self.cycle_loss_fn(real_y, cycled_y) * self.lambda_cycle
            cycle_loss_F = self.cycle_loss_fn(real_x, cycled_x) * self.lambda_cycle

            # Generator identity loss
            id_loss_G = (
                self.identity_loss_fn(real_y, same_y)
                * self.lambda_cycle
                * self.lambda_identity
            )
            id_loss_F = (
                self.identity_loss_fn(real_x, same_x)
                * self.lambda_cycle
                * self.lambda_identity
            )

            # Total generator loss
            total_loss_G = gen_G_loss + cycle_loss_G + id_loss_G
            total_loss_F = gen_F_loss + cycle_loss_F + id_loss_F

            # Discriminator loss
            disc_X_loss = self.discriminator_loss_fn(disc_real_x, disc_fake_x)
            disc_Y_loss = self.discriminator_loss_fn(disc_real_y, disc_fake_y)

        # Get the gradients for the generators
        grads_G = tape.gradient(total_loss_G, self.gen_G.trainable_variables)
        grads_F = tape.gradient(total_loss_F, self.gen_F.trainable_variables)

        # Get the gradients for the discriminators
        disc_X_grads = tape.gradient(disc_X_loss, self.disc_X.trainable_variables)
        disc_Y_grads = tape.gradient(disc_Y_loss, self.disc_Y.trainable_variables)

        # Update the weights of the generators
        self.gen_G_optimizer.apply_gradients(
            zip(grads_G, self.gen_G.trainable_variables)
        )
        self.gen_F_optimizer.apply_gradients(
            zip(grads_F, self.gen_F.trainable_variables)
        )

        # Update the weights of the discriminators
        self.disc_X_optimizer.apply_gradients(
            zip(disc_X_grads, self.disc_X.trainable_variables)
        )
        self.disc_Y_optimizer.apply_gradients(
            zip(disc_Y_grads, self.disc_Y.trainable_variables)
        )

        return {
            "G_loss": total_loss_G,
            "F_loss": total_loss_F,
            "D_X_loss": disc_X_loss,
            "D_Y_loss": disc_Y_loss,
        }

# %% [markdown]
# ### Create a callback that periodically saves generated images

# %%
class GANMonitor(keras.callbacks.Callback):
    """A callback to generate and save images after each epoch"""

    def __init__(self, num_img=4):
        self.num_img = num_img

    def on_epoch_end(self, epoch, logs=None):
        _, ax = plt.subplots(4, 2, figsize=(5, 10))
        for i, img in enumerate(test_ori.take(self.num_img)):
        # for i, img in enumerate(test_ori[:self.num_img]):
            prediction = self.model.gen_G(img)[0].numpy()
            prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
            img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

            ax[i, 0].imshow(img)
            ax[i, 1].imshow(prediction)
            ax[i, 0].set_title("Input image")
            ax[i, 1].set_title("Translated image")
            ax[i, 0].axis("off")
            ax[i, 1].axis("off")

            prediction = keras.preprocessing.image.img_to_array(prediction)
            
            normalized_prediction = (prediction - prediction.min()) / (prediction.max() - prediction.min())
            
            save_img_path = os.path.join(now_time_path, "save_img", 
                                         "generated_img_{i}_{epoch}.png".format(i=i, epoch=epoch + 1)
            )
            
            mpimg.imsave(save_img_path,
                         normalized_prediction
            )

        plt.show()
        plt.close()

# %% [markdown]
# ### Train the end-to-end model

# %%
# Loss function for evaluating adversarial loss
adv_loss_fn = keras.losses.MeanSquaredError()

# Define the loss function for the generators
def generator_loss_fn(fake):
    fake_loss = adv_loss_fn(tf.ones_like(fake), fake)
    return fake_loss


# Define the loss function for the discriminators
def discriminator_loss_fn(real, fake):
    real_loss = adv_loss_fn(tf.ones_like(real), real)
    fake_loss = adv_loss_fn(tf.zeros_like(fake), fake)
    return (real_loss + fake_loss) * 0.5


# Create cycle gan model
cycle_gan_model = CycleGan(
    generator_G=gen_G, generator_F=gen_F, discriminator_X=disc_X, discriminator_Y=disc_Y
)

# Compile the model
cycle_gan_model.compile(
    gen_G_optimizer=keras.optimizers.Adam(learning_rate=2e-4, beta_1=0.5),
    gen_F_optimizer=keras.optimizers.Adam(learning_rate=2e-4, beta_1=0.5),
    disc_X_optimizer=keras.optimizers.Adam(learning_rate=2e-4, beta_1=0.5),
    disc_Y_optimizer=keras.optimizers.Adam(learning_rate=2e-4, beta_1=0.5),
    gen_loss_fn=generator_loss_fn,
    disc_loss_fn=discriminator_loss_fn,
)
# Callbacks
plotter = GANMonitor()
checkpoint_filepath = os.path.join(now_time_path, "model_checkpoints", "cyclegan_checkpoints.{epoch:03d}")
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, save_weights_only=True
)

# Here we will train the model for just one epoch as each epoch takes around
# 7 minutes on a single P100 backed machine.
cycle_gan_model.fit(
    tf.data.Dataset.zip((train_ori, train_nbi)),
    epochs=50,
    callbacks=[plotter, model_checkpoint_callback],
)
